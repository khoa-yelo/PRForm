# %% [markdown]
# # GFF Parsing with Biopython (BCBio)
#
# This notebook demonstrates how to parse a GFF3 file using `bcbio-gff` as suggested in the [Biopython Wiki](https://biopython.org/wiki/GFF_Parsing).

# %%
from BCBio import GFF
from Bio import SeqIO
import os
import pandas as pd
import os
import glob
import subprocess
import shutil
import gc

# %%
# Set the path to the GFF file
gff_file = "../viral_data_all/ncbi_dataset/data_subset/GCF_000864765.1/genomic.gff"

if not os.path.exists(gff_file):
    print(f"Error: {gff_file} not found.")
else:
    print(f"Found GFF file: {gff_file}")
# Out:
# Found GFF file: ../viral_data_all/ncbi_dataset/data_subset/GCF_000864765.1/genomic.gff

# %%
import os
import glob
import subprocess
import shutil

# 1. Define Paths
data_dir = '../viral_data_all/ncbi_dataset/data_subset/'

# 2. Identify the target FASTA files
# finding all files starting with GCA, GCF, ending with _genomic.fna, without 'cds'
file_pattern = '**/genomic.gff'

gff_files = [f for f in glob.glob(os.path.join(data_dir, file_pattern), recursive=True) if 'cds' not in os.path.basename(f)]

print(f"Found {len(gff_files)} GFF files matching the pattern.")
# Out:
# Found 211307 GFF files matching the pattern.

# %%
type(gff_files)
# Out:
# list

# %% [markdown]
# ## Recursive Search for "slip"
#
# GFF files often have nested features (e.g., CDS inside an mRNA inside a gene). To find all instances of "slip", we need to search recursively through all levels of features.

# %%
def search_features_recursive(features, search_term, record_id):
    results = []
    for feature in features:
        match = False
        
        # Check feature type
        if search_term in str(feature.type).lower():
            match = True
        
        # Check all qualifiers (attributes like 'Note', 'exception', etc.)
        if not match:
            for key, values in feature.qualifiers.items():
                for val in values:
                    if search_term in str(val).lower():
                        match = True
                        break
                if match: break
        
        if match:
            results.append({
                "record_id": record_id,
                "type": feature.type,
                "start": int(feature.location.start) + 1,
                "end": int(feature.location.end),
                "strand": feature.location.strand,
                "qualifiers": feature.qualifiers
            })
        
        # Recursively search through sub-features (children)
        if hasattr(feature, 'sub_features') and feature.sub_features:
            results.extend(search_features_recursive(feature.sub_features, search_term, record_id))
            
    return results

# %%
##### SINGLE FILE TESTING ######

# all_slip_matches = []
# search_term = "slip"

# with open(gff_file) as in_handle:
#     for record in GFF.parse(in_handle):
#         matches = search_features_recursive(record.features, search_term, record.id)
#         all_slip_matches.extend(matches)

# print(f"Found {len(all_slip_matches)} total features matching '{search_term}'.")

# if all_slip_matches:
#     df_slip = pd.DataFrame(all_slip_matches)
#     display(df_slip.drop(columns=['qualifiers']).head())
    
#     print("\nFull attributes of the first match:")
#     import pprint
#     pprint.pprint(all_slip_matches[0]['qualifiers'])

# %%
all_matches = []
error_files = []
search_terms = ["slip"] # don't want 'ribosome_binding_site'
checkpoint_dir = "../gff_results/gff_checkpoints"
os.makedirs(checkpoint_dir, exist_ok=True)
checkpoint_interval = 10000
checkpoint_count = 0

for i, gff_file in enumerate(gff_files):
    try:
        with open(gff_file) as in_handle:
            for record in GFF.parse(in_handle):
                for search_term in search_terms:
                    matches = search_features_recursive(record.features, search_term, record.id)
                    for match in matches:
                        match["search_term"] = search_term
                        match["source_file"] = gff_file
                    all_matches.extend(matches)
    except Exception as e:
        print(f"Error parsing {gff_file}: {e}")
        error_files.append(gff_file)
        continue
    # Checkpoint: save and flush every 10,000 files
    if (i + 1) % checkpoint_interval == 0:
        if all_matches:
            df_chunk = pd.DataFrame(all_matches)
            df_chunk.to_csv(f"{checkpoint_dir}/checkpoint_{checkpoint_count}.csv", index=False)
            print(f"[{i+1}/{len(gff_files)}] Saved checkpoint_{checkpoint_count}.csv ({len(df_chunk)} rows)")
            checkpoint_count += 1
            all_matches = []  # free memory
            del df_chunk
            gc.collect()
        else:
            print(f"[{i+1}/{len(gff_files)}] No matches in this batch, skipping checkpoint.")
# Save any remaining matches after the loop
if all_matches:
    df_chunk = pd.DataFrame(all_matches)
    df_chunk.to_csv(f"{checkpoint_dir}/checkpoint_{checkpoint_count}.csv", index=False)
    print(f"[{len(gff_files)}/{len(gff_files)}] Saved final checkpoint_{checkpoint_count}.csv ({len(df_chunk)} rows)")
    del df_chunk
    gc.collect()
# # --- Merge all checkpoints into one DataFrame ---
# checkpoint_files = sorted(
#     [f for f in os.listdir(checkpoint_dir) if f.startswith("checkpoint_") and f.endswith(".csv")]
# )
# print(f"\nMerging {len(checkpoint_files)} checkpoint files...")
# df_all = pd.concat([pd.read_csv(f"{checkpoint_dir}/{f}") for f in checkpoint_files], ignore_index=True)
# df_all = df_all.drop_duplicates(subset=["record_id", "type", "start", "end", "strand"])
# print(f"Found {len(df_all)} unique features matching {search_terms} across {len(gff_files)} files.")
# if error_files:
#     print(f"Failed to parse {len(error_files)} files.")
# display(df_all.drop(columns=['qualifiers']).head(20))
# Out:
# Error parsing ../viral_data_all/ncbi_dataset/data_subset/GCA_003108865.1/genomic.gff: Did not find remapped ID location: gene-tat, [[5846, 6061], [8371, 8462]], [5846, 8462]
# [10000/211307] Saved checkpoint_0.csv (11797 rows)
# Error parsing ../viral_data_all/ncbi_dataset/data_subset/GCA_003108965.1/genomic.gff: Did not find remapped ID location: gene-tat, [[5895, 6107], [8461, 8600]], [5895, 8600]
# [20000/211307] Saved checkpoint_1.csv (11726 rows)
# Error parsing ../viral_data_all/ncbi_dataset/data_subset/GCA_031239455.1/genomic.gff: Did not find remapped ID location: gene-tRNA-Arg (TCT), [[101529, 101568], [101482, 101519]], [101482, 101568]
# [30000/211307] Saved checkpoint_2.csv (11801 rows)
# [40000/211307] Saved checkpoint_3.csv (11785 rows)
# [50000/211307] Saved checkpoint_4.csv (11814 rows)
# [60000/211307] Saved checkpoint_5.csv (11802 rows)
# Error parsing ../viral_data_all/ncbi_dataset/data_subset/GCF_000844405.1/genomic.gff: Did not find remapped ID location: gene-CcBV_6.3, [[14873, 15457], [12589, 14873], [12460, 12589], [12229, 12460], [11958, 12229], [11843, 11958], [11759, 11843], [11640, 11759], [9127, 15230], [9127, 11640]], [0, 227]
# [70000/211307] Saved checkpoint_6.csv (11990 rows)
# Error parsing ../viral_data_all/ncbi_dataset/data_subset/GCA_002402265.1/genomic.gff: Did not find remapped ID location: gene-EBNA-LP, [[14351, 14352], [14383, 14410], [14553, 14619], [14700, 14832], [17423, 17424], [17625, 17691], [17772, 17904], [20495, 20496], [20697, 20763], [20844, 20976], [23567, 23568], [23769, 23835], [23916, 24048], [26639, 26640], [26841, 26907], [26988, 27120], [29711, 29712], [29913, 29979], [30060, 30192], [32783, 32784], [32985, 33051], [33132, 33264], [35472, 35505], [35589, 35711]], [36097, 36156]
# [80000/211307] Saved checkpoint_7.csv (11958 rows)
# Error parsing ../viral_data_all/ncbi_dataset/data_subset/GCF_000850265.1/genomic.gff: Did not find remapped ID location: gene-WDSVgp2, [[0, 246], [5855, 12708]], [0, 12708]
# Error parsing ../viral_data_all/ncbi_dataset/data_subset/GCA_003071505.1/genomic.gff: Did not find remapped ID location: gene-tRNA-Leu, [[31601, 31642], [31537, 31581]], [31537, 31642]
# Error parsing ../viral_data_all/ncbi_dataset/data_subset/GCA_000853945.1/genomic.gff: Did not find remapped ID location: gene-RZ+, [[328, 335], [334, 336], [0, 46]], [328, 381]
# [90000/211307] Saved checkpoint_8.csv (11714 rows)
# [100000/211307] Saved checkpoint_9.csv (11956 rows)
# [110000/211307] Saved checkpoint_10.csv (12028 rows)
# [120000/211307] Saved checkpoint_11.csv (11921 rows)
# Error parsing ../viral_data_all/ncbi_dataset/data_subset/GCA_000873645.1/genomic.gff: Did not find remapped ID location: gene-tRNA-Lys, [[17199, 17237], [17151, 17187]], [17151, 17237]
# [130000/211307] Saved checkpoint_12.csv (11931 rows)
# [140000/211307] Saved checkpoint_13.csv (11964 rows)
# Error parsing ../viral_data_all/ncbi_dataset/data_subset/GCF_003047555.1/genomic.gff: Did not find remapped ID location: gene-D1Y56_gs1, [[326, 333], [332, 334], [0, 46]], [326, 379]
# [150000/211307] Saved checkpoint_14.csv (12081 rows)
# Error parsing ../viral_data_all/ncbi_dataset/data_subset/GCA_000844405.1/genomic.gff: Did not find remapped ID location: gene-CcBV_6.3, [[14873, 15457], [12589, 14873], [12460, 12589], [12229, 12460], [11958, 12229], [11843, 11958], [11759, 11843], [11640, 11759], [9127, 15230], [9127, 11640]], [0, 227]
# [160000/211307] Saved checkpoint_15.csv (11963 rows)
# Error parsing ../viral_data_all/ncbi_dataset/data_subset/GCA_000857425.1/genomic.gff: Did not find remapped ID location: gene-pol, [[0, 57], [1570, 10479]], [0, 10479]
# [170000/211307] Saved checkpoint_16.csv (11811 rows)
# Error parsing ../viral_data_all/ncbi_dataset/data_subset/GCA_003108845.1/genomic.gff: Did not find remapped ID location: gene-tat, [[5888, 6103], [8416, 8507]], [5888, 8507]
# [180000/211307] Saved checkpoint_17.csv (11848 rows)
# Error parsing ../viral_data_all/ncbi_dataset/data_subset/GCA_003108945.1/genomic.gff: Did not find remapped ID location: gene-tat, [[5916, 6107], [8494, 8576]], [5916, 8576]
# [190000/211307] Saved checkpoint_18.csv (11974 rows)
# Error parsing ../viral_data_all/ncbi_dataset/data_subset/GCF_002709885.1/genomic.gff: Did not find remapped ID location: gene-KNT57_gp001, [[0, 53], [193572, 193624]], [193624, 193677]
# [200000/211307] Saved checkpoint_19.csv (11964 rows)
# [210000/211307] Saved checkpoint_20.csv (11831 rows)
# [211307/211307] Saved final checkpoint_21.csv (1573 rows)

# %%
import re
from collections import defaultdict

def fallback_parse_gff(gff_file, search_terms):
    """Raw text-based GFF parser for files that BCBio can't handle."""
    results = []
    with open(gff_file) as f:
        for line in f:
            if line.startswith("#"):
                continue
            parts = line.strip().split("\t")
            if len(parts) < 9:
                continue
            
            seqid, source, ftype, start, end, score, strand, phase, attributes = parts
            
            # Check if any search term matches the feature type or attributes
            line_lower = (ftype + "\t" + attributes).lower()
            for term in search_terms:
                if term in line_lower:
                    # Parse attributes into a dict
                    quals = {}
                    for attr in attributes.split(";"):
                        if "=" in attr:
                            k, v = attr.split("=", 1)
                            quals[k] = [v]
                    
                    results.append({
                        "record_id": seqid,
                        "type": ftype,
                        "start": int(start) - 1,  # GFF is 1-based, convert to 0-based
                        "end": int(end),
                        "strand": 1 if strand == "+" else (-1 if strand == "-" else 0),
                        "qualifiers": quals,
                        "search_term": term,
                        "source_file": gff_file,
                    })
                    break  # avoid duplicate matches for same line
    return results

# Deduplicate the file list
error_files = list(dict.fromkeys(error_files))

search_terms = ["slip", "ribosome", "ribosomal"]
fallback_matches = []

for gff_file in error_files:
    try:
        matches = fallback_parse_gff(gff_file, search_terms)
        fallback_matches.extend(matches)
        print(f"✓ {gff_file}: {len(matches)} matches found")
    except FileNotFoundError:
        print(f"✗ {gff_file}: FILE NOT FOUND")
    except Exception as e:
        print(f"✗ {gff_file}: {e}")

print(f"\nTotal fallback matches: {len(fallback_matches)}")

# Convert to DataFrame
if fallback_matches:
    df_fallback = pd.DataFrame(fallback_matches)
    df_fallback = df_fallback.drop_duplicates(subset=["record_id", "type", "start", "end", "strand"])
    print(f"Unique fallback features: {len(df_fallback)}")
    display(df_fallback.drop(columns=["qualifiers"]).head(20))

df_fallback.to_csv("../gff_results/gff_checkpoints/checkpoint_errors.csv", index=False)
print("Saved features to checkpoint_errors.csv")
# Out:
# ✓ ../viral_data_all/ncbi_dataset/data_subset/GCA_003108865.1/genomic.gff: 0 matches found
# ✓ ../viral_data_all/ncbi_dataset/data_subset/GCA_003108965.1/genomic.gff: 2 matches found
# ✓ ../viral_data_all/ncbi_dataset/data_subset/GCA_031239455.1/genomic.gff: 0 matches found
# ✓ ../viral_data_all/ncbi_dataset/data_subset/GCF_000844405.1/genomic.gff: 0 matches found
# ✓ ../viral_data_all/ncbi_dataset/data_subset/GCA_002402265.1/genomic.gff: 0 matches found
# ✓ ../viral_data_all/ncbi_dataset/data_subset/GCF_000850265.1/genomic.gff: 0 matches found
# ✓ ../viral_data_all/ncbi_dataset/data_subset/GCA_003071505.1/genomic.gff: 0 matches found
# ✓ ../viral_data_all/ncbi_dataset/data_subset/GCA_000853945.1/genomic.gff: 0 matches found
# ✓ ../viral_data_all/ncbi_dataset/data_subset/GCA_000873645.1/genomic.gff: 0 matches found
# ✓ ../viral_data_all/ncbi_dataset/data_subset/GCF_003047555.1/genomic.gff: 0 matches found
# ✓ ../viral_data_all/ncbi_dataset/data_subset/GCA_000844405.1/genomic.gff: 0 matches found
# ✓ ../viral_data_all/ncbi_dataset/data_subset/GCA_000857425.1/genomic.gff: 0 matches found
# ✓ ../viral_data_all/ncbi_dataset/data_subset/GCA_003108845.1/genomic.gff: 0 matches found
# ✓ ../viral_data_all/ncbi_dataset/data_subset/GCA_003108945.1/genomic.gff: 2 matches found
# ✓ ../viral_data_all/ncbi_dataset/data_subset/GCF_002709885.1/genomic.gff: 0 matches found
#
# Total fallback matches: 4
# Unique fallback features: 4
#     record_id type  start   end  strand search_term  \
# 0  AJ302647.1  CDS    843  2151       1        slip
# 1  AJ302647.1  CDS   2150  5180       1        slip
# 2  AJ302646.1  CDS    843  2151       1        slip
# 3  AJ302646.1  CDS   2150  5180       1        slip
#
#                                          source_file
# 0  ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 1  ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 2  ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 3  ../viral_data_all/ncbi_dataset/data_subset/GCA...
# Saved features to checkpoint_errors.csv

# %%
### Checking what the errors are ################################################

import re
from collections import defaultdict
# Files that errored (extracted from your output)
print(error_files)
# --- Diagnose each file ---
for gff_file in error_files:
    print(f"\n{'='*80}")
    print(f"FILE: {gff_file}")
    print(f"{'='*80}")
    
    # Collect all feature lines and look for multi-part / trans-spliced genes
    feature_ids = defaultdict(list)
    
    try:
        with open(gff_file) as f:
            for line_num, line in enumerate(f, 1):
                if line.startswith("#"):
                    continue
                parts = line.strip().split("\t")
                if len(parts) < 9:
                    continue
                
                seqid, source, ftype, start, end, score, strand, phase, attributes = parts
                
                # Parse the ID and Parent from attributes
                attr_dict = {}
                for attr in attributes.split(";"):
                    if "=" in attr:
                        key, val = attr.split("=", 1)
                        attr_dict[key] = val
                
                feat_id = attr_dict.get("ID", "")
                parent = attr_dict.get("Parent", "")
                
                feature_ids[feat_id].append({
                    "line": line_num,
                    "type": ftype,
                    "start": start,
                    "end": end,
                    "strand": strand,
                    "parent": parent,
                })
        
        # Find features with the same ID appearing multiple times (discontinuous)
        print("\nFeatures with DUPLICATE IDs (multi-part/discontinuous locations):")
        found_any = False
        for feat_id, entries in feature_ids.items():
            if len(entries) > 1:
                found_any = True
                print(f"\n  ID: {feat_id} — appears {len(entries)} times")
                for e in entries:
                    print(f"    Line {e['line']}: {e['type']}  {e['start']}-{e['end']}  "
                          f"strand={e['strand']}  parent={e['parent']}")
        
        if not found_any:
            # Also check for join() in attributes or non-standard location encodings
            print("  (No duplicate IDs found — checking for 'join' or complex parents...)")
            
    except FileNotFoundError:
        print(f"  FILE NOT FOUND — skipping")
    except Exception as e:
        print(f"  Error reading file: {e}")
# Out:
# ['../viral_data_all/ncbi_dataset/data_subset/GCA_003108865.1/genomic.gff', '../viral_data_all/ncbi_dataset/data_subset/GCA_003108965.1/genomic.gff', '../viral_data_all/ncbi_dataset/data_subset/GCA_031239455.1/genomic.gff', '../viral_data_all/ncbi_dataset/data_subset/GCF_000844405.1/genomic.gff', '../viral_data_all/ncbi_dataset/data_subset/GCA_002402265.1/genomic.gff', '../viral_data_all/ncbi_dataset/data_subset/GCF_000850265.1/genomic.gff', '../viral_data_all/ncbi_dataset/data_subset/GCA_003071505.1/genomic.gff', '../viral_data_all/ncbi_dataset/data_subset/GCA_000853945.1/genomic.gff', '../viral_data_all/ncbi_dataset/data_subset/GCA_000873645.1/genomic.gff', '../viral_data_all/ncbi_dataset/data_subset/GCF_003047555.1/genomic.gff', '../viral_data_all/ncbi_dataset/data_subset/GCA_000844405.1/genomic.gff', '../viral_data_all/ncbi_dataset/data_subset/GCA_000857425.1/genomic.gff', '../viral_data_all/ncbi_dataset/data_subset/GCA_003108845.1/genomic.gff', '../viral_data_all/ncbi_dataset/data_subset/GCA_003108945.1/genomic.gff', '../viral_data_all/ncbi_dataset/data_subset/GCF_002709885.1/genomic.gff']
#
# ================================================================================
# FILE: ../viral_data_all/ncbi_dataset/data_subset/GCA_003108865.1/genomic.gff
# ================================================================================
#
# Features with DUPLICATE IDs (multi-part/discontinuous locations):
#
#   ID: gene-tat — appears 2 times
#     Line 17: gene  5847-6061  strand=+  parent=
#     Line 18: gene  8372-8462  strand=+  parent=
#
#   ID: cds-CAB98172.1 — appears 2 times
#     Line 23: CDS  5847-6061  strand=+  parent=rna-tat
#     Line 24: CDS  8372-8462  strand=+  parent=rna-tat
#
#   ID: gene-rev — appears 2 times
#     Line 26: gene  5986-6061  strand=+  parent=
#     Line 27: gene  8372-8646  strand=+  parent=
#
#   ID: cds-CAB98173.1 — appears 2 times
#     Line 33: CDS  5986-6061  strand=+  parent=rna-rev
#     Line 34: CDS  8372-8646  strand=+  parent=rna-rev
#
# ================================================================================
# FILE: ../viral_data_all/ncbi_dataset/data_subset/GCA_003108965.1/genomic.gff
# ================================================================================
#
# Features with DUPLICATE IDs (multi-part/discontinuous locations):
#
#   ID: cds-CAC38421.2 — appears 2 times
#     Line 10: CDS  844-2151  strand=+  parent=gene-gag-pol
#     Line 11: CDS  2151-5180  strand=+  parent=gene-gag-pol
#
#   ID: gene-tat — appears 2 times
#     Line 18: gene  5896-6107  strand=+  parent=
#     Line 19: gene  8462-8600  strand=+  parent=
#
#   ID: cds-CAC38424.1 — appears 2 times
#     Line 24: CDS  5896-6107  strand=+  parent=rna-tat
#     Line 25: CDS  8462-8600  strand=+  parent=rna-tat
#
#   ID: gene-rev — appears 2 times
#     Line 27: gene  6035-6107  strand=+  parent=
#     Line 28: gene  8462-8703  strand=+  parent=
#
#   ID: cds-CAC38425.1 — appears 2 times
#     Line 34: CDS  6035-6107  strand=+  parent=rna-rev
#     Line 35: CDS  8462-8703  strand=+  parent=rna-rev
#
# ================================================================================
# FILE: ../viral_data_all/ncbi_dataset/data_subset/GCA_031239455.1/genomic.gff
# ================================================================================
#
# Features with DUPLICATE IDs (multi-part/discontinuous locations):
#
#   ID: gene-tRNA-Arg (TCT) — appears 2 times
#     Line 165: gene  101530-101568  strand=-  parent=
#     Line 166: gene  101483-101519  strand=-  parent=
#
# ================================================================================
# FILE: ../viral_data_all/ncbi_dataset/data_subset/GCF_000844405.1/genomic.gff
# ================================================================================
#
# Features with DUPLICATE IDs (multi-part/discontinuous locations):
#
#   ID: cds-YP_184759.1 — appears 2 times
#     Line 22: CDS  6832-6886  strand=+  parent=gene-CcBV_1.3
#     Line 23: CDS  7046-7797  strand=+  parent=gene-CcBV_1.3
#
#   ID: cds-YP_184760.1 — appears 3 times
#     Line 32: CDS  9114-9168  strand=+  parent=gene-CcBV_1.4
#     Line 33: CDS  9468-9545  strand=+  parent=gene-CcBV_1.4
#     Line 34: CDS  10191-10573  strand=+  parent=gene-CcBV_1.4
#
#   ID: cds-YP_184761.1 — appears 3 times
#     Line 45: CDS  12127-12181  strand=+  parent=gene-CcBV_1.5
#     Line 46: CDS  12481-12540  strand=+  parent=gene-CcBV_1.5
#     Line 47: CDS  13181-13950  strand=+  parent=gene-CcBV_1.5
#
#   ID: cds-YP_184767.1 — appears 2 times
#     Line 76: CDS  23597-24006  strand=+  parent=gene-CcBV_1.11
#     Line 77: CDS  24029-24551  strand=+  parent=gene-CcBV_1.11
#
#   ID: cds-YP_184768.1 — appears 2 times
#     Line 93: CDS  2866-2923  strand=+  parent=gene-CcBV_2.1
#     Line 94: CDS  3041-3912  strand=+  parent=gene-CcBV_2.1
#
#   ID: cds-YP_184769.1 — appears 2 times
#     Line 99: CDS  5491-5539  strand=+  parent=gene-CcBV_2.2
#     Line 100: CDS  5660-6597  strand=+  parent=gene-CcBV_2.2
#
#   ID: cds-YP_184770.1 — appears 2 times
#     Line 107: CDS  8546-9528  strand=-  parent=gene-CcBV_2.3
#     Line 108: CDS  8036-8336  strand=-  parent=gene-CcBV_2.3
#
#   ID: cds-YP_184771.1 — appears 2 times
#     Line 115: CDS  10411-10465  strand=+  parent=gene-CcBV_2.4
#     Line 116: CDS  10688-11511  strand=+  parent=gene-CcBV_2.4
#
#   ID: cds-YP_184772.1 — appears 2 times
#     Line 126: CDS  14197-14251  strand=+  parent=gene-CcBV_2.5
#     Line 127: CDS  14336-14736  strand=+  parent=gene-CcBV_2.5
#
#   ID: cds-YP_184773.1 — appears 5 times
#     Line 136: CDS  1608-1878  strand=-  parent=gene-CcBV_3.1
#     Line 137: CDS  1266-1385  strand=-  parent=gene-CcBV_3.1
#     Line 138: CDS  988-1129  strand=-  parent=gene-CcBV_3.1
#     Line 139: CDS  708-834  strand=-  parent=gene-CcBV_3.1
#     Line 140: CDS  583-651  strand=-  parent=gene-CcBV_3.1
#
#   ID: cds-YP_184774.1 — appears 2 times
#     Line 154: CDS  3321-3376  strand=-  parent=gene-CcBV_3.2
#     Line 155: CDS  2868-3012  strand=-  parent=gene-CcBV_3.2
#
#   ID: cds-YP_184775.1 — appears 7 times
#     Line 164: CDS  9275-9347  strand=-  parent=gene-CcBV_3.3
#     Line 165: CDS  9003-9149  strand=-  parent=gene-CcBV_3.3
#     Line 166: CDS  8487-8873  strand=-  parent=gene-CcBV_3.3
#     Line 167: CDS  7446-8330  strand=-  parent=gene-CcBV_3.3
#     Line 168: CDS  6994-7262  strand=-  parent=gene-CcBV_3.3
#     Line 169: CDS  6281-6443  strand=-  parent=gene-CcBV_3.3
#     Line 170: CDS  6135-6238  strand=-  parent=gene-CcBV_3.3
#
#   ID: cds-YP_184776.1 — appears 3 times
#     Line 185: CDS  14457-14739  strand=-  parent=gene-CcBV_3.4
#     Line 186: CDS  14276-14350  strand=-  parent=gene-CcBV_3.4
#     Line 187: CDS  10881-14194  strand=-  parent=gene-CcBV_3.4
#
#   ID: cds-YP_184780.1 — appears 4 times
#     Line 224: CDS  2825-3036  strand=-  parent=gene-CcBV_4.1a
#     Line 225: CDS  1860-1964  strand=-  parent=gene-CcBV_4.1a
#     Line 226: CDS  1690-1788  strand=-  parent=gene-CcBV_4.1a
#     Line 227: CDS  1066-1180  strand=-  parent=gene-CcBV_4.1a
#
#   ID: cds-YP_184781.1 — appears 5 times
#     Line 228: CDS  2825-3036  strand=-  parent=gene-CcBV_4.1a
#     Line 229: CDS  2064-2165  strand=-  parent=gene-CcBV_4.1a
#     Line 230: CDS  1860-1964  strand=-  parent=gene-CcBV_4.1a
#     Line 231: CDS  1690-1788  strand=-  parent=gene-CcBV_4.1a
#     Line 232: CDS  1066-1180  strand=-  parent=gene-CcBV_4.1a
#
#   ID: cds-YP_184785.1 — appears 2 times
#     Line 276: CDS  1309-1363  strand=+  parent=gene-CcBV_5.1
#     Line 277: CDS  1569-3769  strand=+  parent=gene-CcBV_5.1
#
#   ID: cds-YP_184786.1 — appears 2 times
#     Line 282: CDS  4791-4845  strand=-  parent=gene-CcBV_5.2
#     Line 283: CDS  4342-4688  strand=-  parent=gene-CcBV_5.2
#
#   ID: cds-YP_184787.1 — appears 2 times
#     Line 302: CDS  9724-9778  strand=-  parent=gene-CcBV_5.3
#     Line 303: CDS  9277-9605  strand=-  parent=gene-CcBV_5.3
#
#   ID: cds-YP_184788.1 — appears 2 times
#     Line 309: CDS  10562-10595  strand=+  parent=gene-CcBV_5.4
#     Line 310: CDS  10701-10846  strand=+  parent=gene-CcBV_5.4
#
#   ID: cds-YP_184789.1 — appears 2 times
#     Line 315: CDS  13413-13461  strand=-  parent=gene-CcBV_5.5
#     Line 316: CDS  12475-13271  strand=-  parent=gene-CcBV_5.5
#
#   ID: cds-YP_184791.1 — appears 3 times
#     Line 324: CDS  1840-2167  strand=-  parent=gene-CcBV_6.1
#     Line 325: CDS  571-787  strand=-  parent=gene-CcBV_6.1
#     Line 326: CDS  229-364  strand=-  parent=gene-CcBV_6.1
#
#   ID: cds-YP_184792.1 — appears 3 times
#     Line 339: CDS  6052-6504  strand=-  parent=gene-CcBV_6.2
#     Line 340: CDS  5456-6030  strand=-  parent=gene-CcBV_6.2
#     Line 341: CDS  4409-5318  strand=-  parent=gene-CcBV_6.2
#
#   ID: gene-CcBV_6.3 — appears 10 times
#     Line 349: gene  14874-15457  strand=-  parent=
#     Line 350: gene  12590-14873  strand=-  parent=
#     Line 351: gene  12461-12589  strand=-  parent=
#     Line 352: gene  12230-12460  strand=-  parent=
#     Line 353: gene  11959-12229  strand=-  parent=
#     Line 354: gene  11844-11958  strand=-  parent=
#     Line 355: gene  11760-11843  strand=-  parent=
#     Line 356: gene  11641-11759  strand=-  parent=
#     Line 357: gene  9128-15230  strand=-  parent=
#     Line 358: gene  9128-11640  strand=-  parent=
#
#   ID: cds-YP_184790.1 — appears 5 times
#     Line 359: CDS  14874-15457  strand=-  parent=gene-CcBV_6.3
#     Line 360: CDS  12461-12599  strand=-  parent=gene-CcBV_6.3
#     Line 361: CDS  11959-12229  strand=-  parent=gene-CcBV_6.3
#     Line 362: CDS  11760-11843  strand=-  parent=gene-CcBV_6.3
#     Line 363: CDS  9128-11640  strand=-  parent=gene-CcBV_6.3
#
#   ID: gene-CcBV_7.1 — appears 8 times
#     Line 379: gene  4-2421  strand=-  parent=
#     Line 380: gene  4-884  strand=-  parent=
#     Line 381: gene  24748-24751  strand=-  parent=
#     Line 382: gene  24711-24747  strand=-  parent=
#     Line 383: gene  2197-2421  strand=-  parent=
#     Line 384: gene  1983-2196  strand=-  parent=
#     Line 385: gene  1719-1982  strand=-  parent=
#     Line 386: gene  885-1718  strand=-  parent=
#
#   ID: cds-YP_184793.1 — appears 4 times
#     Line 387: CDS  26945-27169  strand=-  parent=gene-CcBV_7.1
#     Line 388: CDS  26467-26730  strand=-  parent=gene-CcBV_7.1
#     Line 389: CDS  24752-25632  strand=-  parent=gene-CcBV_7.1
#     Line 390: CDS  24711-24747  strand=-  parent=gene-CcBV_7.1
#
#   ID: cds-YP_184794.1 — appears 4 times
#     Line 404: CDS  5423-6710  strand=+  parent=gene-CcBV_7.2
#     Line 405: CDS  7007-7125  strand=+  parent=gene-CcBV_7.2
#     Line 406: CDS  7250-7453  strand=+  parent=gene-CcBV_7.2
#     Line 407: CDS  7459-7791  strand=+  parent=gene-CcBV_7.2
#
#   ID: cds-YP_184797.1 — appears 2 times
#     Line 440: CDS  22149-22200  strand=-  parent=gene-CcBV_7.5
#     Line 441: CDS  21177-21739  strand=-  parent=gene-CcBV_7.5
#
#   ID: cds-YP_184799.1 — appears 2 times
#     Line 454: CDS  2065-2200  strand=+  parent=gene-CcBV_8.2
#     Line 455: CDS  2407-3167  strand=+  parent=gene-CcBV_8.2
#
#   ID: gene-CcBV_8.1 — appears 6 times
#     Line 464: gene  4930-4981  strand=+  parent=
#     Line 465: gene  4982-5157  strand=+  parent=
#     Line 466: gene  126-200  strand=+  parent=
#     Line 467: gene  126-512  strand=+  parent=
#     Line 468: gene  201-312  strand=+  parent=
#     Line 469: gene  313-512  strand=+  parent=
#
#   ID: cds-YP_184798.1 — appears 3 times
#     Line 470: CDS  4930-4981  strand=+  parent=gene-CcBV_8.1
#     Line 471: CDS  126-200  strand=+  parent=gene-CcBV_8.1
#     Line 472: CDS  313-512  strand=+  parent=gene-CcBV_8.1
#
#   ID: cds-YP_184800.1 — appears 3 times
#     Line 484: CDS  7071-7320  strand=-  parent=gene-CcBV_9.1
#     Line 485: CDS  6876-6956  strand=-  parent=gene-CcBV_9.1
#     Line 486: CDS  4996-6755  strand=-  parent=gene-CcBV_9.1
#
#   ID: cds-YP_184801.1 — appears 2 times
#     Line 494: CDS  9350-9404  strand=-  parent=gene-CcBV_9.2
#     Line 495: CDS  8739-9148  strand=-  parent=gene-CcBV_9.2
#
#   ID: cds-YP_184802.1 — appears 2 times
#     Line 501: CDS  10325-10379  strand=+  parent=gene-CcBV_9.3
#     Line 502: CDS  10546-10874  strand=+  parent=gene-CcBV_9.3
#
#   ID: cds-YP_184803.1 — appears 2 times
#     Line 510: CDS  13472-13526  strand=+  parent=gene-CcBV_9.4
#     Line 511: CDS  13767-14053  strand=+  parent=gene-CcBV_9.4
#
#   ID: cds-YP_184808.1 — appears 5 times
#     Line 537: CDS  10182-10393  strand=-  parent=gene-CcBV_10.5
#     Line 538: CDS  10008-10109  strand=-  parent=gene-CcBV_10.5
#     Line 539: CDS  9828-9932  strand=-  parent=gene-CcBV_10.5
#     Line 540: CDS  9644-9740  strand=-  parent=gene-CcBV_10.5
#     Line 541: CDS  9225-9476  strand=-  parent=gene-CcBV_10.5
#
#   ID: cds-YP_184811.1 — appears 3 times
#     Line 569: CDS  7686-7915  strand=+  parent=gene-CcBV_2-11.1
#     Line 570: CDS  7984-8160  strand=+  parent=gene-CcBV_2-11.1
#     Line 571: CDS  8242-8350  strand=+  parent=gene-CcBV_2-11.1
#
#   ID: cds-YP_184814.1 — appears 2 times
#     Line 595: CDS  6236-6473  strand=-  parent=gene-CcBV_12.2
#     Line 596: CDS  4629-5833  strand=-  parent=gene-CcBV_12.2
#
#   ID: cds-YP_184815.1 — appears 6 times
#     Line 605: CDS  12738-12971  strand=-  parent=gene-CcBV_12.3
#     Line 606: CDS  12567-12656  strand=-  parent=gene-CcBV_12.3
#     Line 607: CDS  12363-12482  strand=-  parent=gene-CcBV_12.3
#     Line 608: CDS  12224-12295  strand=-  parent=gene-CcBV_12.3
#     Line 609: CDS  11843-11920  strand=-  parent=gene-CcBV_12.3
#     Line 610: CDS  10958-11047  strand=-  parent=gene-CcBV_12.3
#
#   ID: cds-YP_184817.1 — appears 2 times
#     Line 646: CDS  7912-7966  strand=-  parent=gene-CcBV_1-13.1
#     Line 647: CDS  7214-7683  strand=-  parent=gene-CcBV_1-13.1
#
#   ID: cds-YP_184818.1 — appears 2 times
#     Line 653: CDS  8792-8992  strand=+  parent=gene-CcBV_2-13.1
#     Line 654: CDS  9181-9459  strand=+  parent=gene-CcBV_2-13.1
#
#   ID: cds-YP_184819.1 — appears 3 times
#     Line 660: CDS  13942-13996  strand=-  parent=gene-CcBV_13.1
#     Line 661: CDS  13327-13848  strand=-  parent=gene-CcBV_13.1
#     Line 662: CDS  11683-12209  strand=-  parent=gene-CcBV_13.1
#
#   ID: cds-YP_184821.1 — appears 2 times
#     Line 678: CDS  20414-20468  strand=-  parent=gene-CcBV_5-13.1
#     Line 679: CDS  18638-20016  strand=-  parent=gene-CcBV_5-13.1
#
#   ID: cds-YP_184828.1 — appears 2 times
#     Line 734: CDS  752-785  strand=+  parent=gene-CcBV_15.1
#     Line 735: CDS  1295-1398  strand=+  parent=gene-CcBV_15.1
#
#   ID: cds-YP_184831.1 — appears 2 times
#     Line 746: CDS  4048-4166  strand=+  parent=gene-CcBV_15.4
#     Line 747: CDS  4246-4351  strand=+  parent=gene-CcBV_15.4
#
#   ID: cds-YP_184832.1 — appears 2 times
#     Line 754: CDS  6937-7020  strand=-  parent=gene-CcBV_15.5
#     Line 755: CDS  6581-6682  strand=-  parent=gene-CcBV_15.5
#
#   ID: cds-YP_184838.1 — appears 2 times
#     Line 784: CDS  1846-1897  strand=+  parent=gene-CcBV_18.2
#     Line 785: CDS  2014-2705  strand=+  parent=gene-CcBV_18.2
#
#   ID: cds-YP_184840.1 — appears 2 times
#     Line 802: CDS  12569-12724  strand=-  parent=gene-CcBV_18.4
#     Line 803: CDS  12223-12486  strand=-  parent=gene-CcBV_18.4
#
#   ID: cds-YP_184841.1 — appears 3 times
#     Line 815: CDS  17672-17701  strand=-  parent=gene-CcBV_18.5
#     Line 816: CDS  16375-16452  strand=-  parent=gene-CcBV_18.5
#     Line 817: CDS  16050-16217  strand=-  parent=gene-CcBV_18.5
#
#   ID: cds-YP_184842.1 — appears 3 times
#     Line 831: CDS  20781-20805  strand=-  parent=gene-CcBV_18.6
#     Line 832: CDS  20472-20558  strand=-  parent=gene-CcBV_18.6
#     Line 833: CDS  19489-20156  strand=-  parent=gene-CcBV_18.6
#
#   ID: cds-YP_184843.1 — appears 2 times
#     Line 840: CDS  23888-24125  strand=-  parent=gene-CcBV_18.7
#     Line 841: CDS  22259-23292  strand=-  parent=gene-CcBV_18.7
#
#   ID: cds-YP_184844.1 — appears 8 times
#     Line 846: CDS  28986-28999  strand=-  parent=gene-CcBV_18.8
#     Line 847: CDS  28791-28947  strand=-  parent=gene-CcBV_18.8
#     Line 848: CDS  28013-28396  strand=-  parent=gene-CcBV_18.8
#     Line 849: CDS  27301-27421  strand=-  parent=gene-CcBV_18.8
#     Line 850: CDS  27110-27239  strand=-  parent=gene-CcBV_18.8
#     Line 851: CDS  26729-26774  strand=-  parent=gene-CcBV_18.8
#     Line 852: CDS  26414-26699  strand=-  parent=gene-CcBV_18.8
#     Line 853: CDS  25846-26336  strand=-  parent=gene-CcBV_18.8
#
#   ID: cds-YP_184845.1 — appears 3 times
#     Line 871: CDS  30006-30282  strand=+  parent=gene-CcBV_18.9
#     Line 872: CDS  30364-30452  strand=+  parent=gene-CcBV_18.9
#     Line 873: CDS  30521-30565  strand=+  parent=gene-CcBV_18.9
#
#   ID: gene-CcBV_18.1 — appears 3 times
#     Line 880: gene  31901-32021  strand=+  parent=
#     Line 881: gene  32022-32138  strand=+  parent=
#     Line 882: gene  31-620  strand=+  parent=
#
#   ID: cds-YP_184837.1 — appears 2 times
#     Line 883: CDS  31901-32021  strand=+  parent=gene-CcBV_18.1
#     Line 884: CDS  31-620  strand=+  parent=gene-CcBV_18.1
#
#   ID: cds-YP_184847.1 — appears 2 times
#     Line 893: CDS  1776-1827  strand=+  parent=gene-CcBV_19.3
#     Line 894: CDS  1913-2916  strand=+  parent=gene-CcBV_19.3
#
#   ID: cds-YP_184848.1 — appears 3 times
#     Line 899: CDS  3605-3659  strand=+  parent=gene-CcBV_19.4
#     Line 900: CDS  3853-3936  strand=+  parent=gene-CcBV_19.4
#     Line 901: CDS  4383-5041  strand=+  parent=gene-CcBV_19.4
#
#   ID: cds-YP_184850.1 — appears 2 times
#     Line 913: CDS  8311-8362  strand=+  parent=gene-CcBV_19.1
#     Line 914: CDS  8448-9433  strand=+  parent=gene-CcBV_19.1
#
#   ID: cds-YP_184852.1 — appears 3 times
#     Line 924: CDS  875-925  strand=+  parent=gene-CcBV_20.1
#     Line 925: CDS  1051-1120  strand=+  parent=gene-CcBV_20.1
#     Line 926: CDS  1161-2035  strand=+  parent=gene-CcBV_20.1
#
#   ID: cds-YP_184853.1 — appears 3 times
#     Line 940: CDS  8119-8368  strand=+  parent=gene-CcBV_20.2
#     Line 941: CDS  8483-8563  strand=+  parent=gene-CcBV_20.2
#     Line 942: CDS  8685-11629  strand=+  parent=gene-CcBV_20.2
#
#   ID: cds-YP_184854.1 — appears 2 times
#     Line 989: CDS  9256-9307  strand=-  parent=gene-CcBV_22.2
#     Line 990: CDS  8711-9093  strand=-  parent=gene-CcBV_22.2
#
#   ID: cds-YP_184855.1 — appears 2 times
#     Line 996: CDS  12121-12172  strand=-  parent=gene-CcBV_22.3
#     Line 997: CDS  11405-11790  strand=-  parent=gene-CcBV_22.3
#
#   ID: cds-YP_184856.1 — appears 2 times
#     Line 1003: CDS  12525-12576  strand=+  parent=gene-CcBV_22.4
#     Line 1004: CDS  12915-14527  strand=+  parent=gene-CcBV_22.4
#
#   ID: cds-YP_184858.1 — appears 2 times
#     Line 1027: CDS  24594-24672  strand=-  parent=gene-CcBV_22.6
#     Line 1028: CDS  23396-24321  strand=-  parent=gene-CcBV_22.6
#
#   ID: cds-YP_184859.1 — appears 5 times
#     Line 1039: CDS  1167-1273  strand=+  parent=gene-CcBV_23.1
#     Line 1040: CDS  1507-1535  strand=+  parent=gene-CcBV_23.1
#     Line 1041: CDS  1704-1901  strand=+  parent=gene-CcBV_23.1
#     Line 1042: CDS  2017-2097  strand=+  parent=gene-CcBV_23.1
#     Line 1043: CDS  2218-4535  strand=+  parent=gene-CcBV_23.1
#
#   ID: cds-YP_184860.1 — appears 5 times
#     Line 1054: CDS  8313-8364  strand=-  parent=gene-CcBV_23.2
#     Line 1055: CDS  7779-8228  strand=-  parent=gene-CcBV_23.2
#     Line 1056: CDS  7558-7668  strand=-  parent=gene-CcBV_23.2
#     Line 1057: CDS  6906-7082  strand=-  parent=gene-CcBV_23.2
#     Line 1058: CDS  6289-6395  strand=-  parent=gene-CcBV_23.2
#
#   ID: cds-YP_184861.1 — appears 2 times
#     Line 1072: CDS  9786-9840  strand=-  parent=gene-CcBV_23.3
#     Line 1073: CDS  9318-9556  strand=-  parent=gene-CcBV_23.3
#
#   ID: cds-YP_184862.1 — appears 3 times
#     Line 1078: CDS  10227-10336  strand=+  parent=gene-CcBV_23.4
#     Line 1079: CDS  10434-11766  strand=+  parent=gene-CcBV_23.4
#     Line 1080: CDS  11852-11992  strand=+  parent=gene-CcBV_23.4
#
#   ID: cds-YP_184863.1 — appears 2 times
#     Line 1093: CDS  728-979  strand=+  parent=gene-CcBV_25.1
#     Line 1094: CDS  1094-1186  strand=+  parent=gene-CcBV_25.1
#
#   ID: cds-YP_184865.1 — appears 2 times
#     Line 1108: CDS  7907-7958  strand=-  parent=gene-CcBV_25.3
#     Line 1109: CDS  6836-7821  strand=-  parent=gene-CcBV_25.3
#
#   ID: cds-YP_184866.1 — appears 2 times
#     Line 1114: CDS  8724-9134  strand=+  parent=gene-CcBV_25.4
#     Line 1115: CDS  9234-9374  strand=+  parent=gene-CcBV_25.4
#
#   ID: cds-YP_184867.1 — appears 2 times
#     Line 1122: CDS  10634-10676  strand=-  parent=gene-CcBV_25.5
#     Line 1123: CDS  10161-10438  strand=-  parent=gene-CcBV_25.5
#
#   ID: cds-YP_184868.1 — appears 4 times
#     Line 1128: CDS  10915-10939  strand=+  parent=gene-CcBV_25.6
#     Line 1129: CDS  12519-12671  strand=+  parent=gene-CcBV_25.6
#     Line 1130: CDS  12759-13200  strand=+  parent=gene-CcBV_25.6
#     Line 1131: CDS  13272-13806  strand=+  parent=gene-CcBV_25.6
#
#   ID: cds-YP_184870.1 — appears 2 times
#     Line 1153: CDS  1825-1967  strand=+  parent=gene-CcBV_26.2
#     Line 1154: CDS  1991-2294  strand=+  parent=gene-CcBV_26.2
#
#   ID: cds-YP_184871.1 — appears 2 times
#     Line 1160: CDS  3370-3510  strand=+  parent=gene-CcBV_26.3
#     Line 1161: CDS  4293-4859  strand=+  parent=gene-CcBV_26.3
#
#   ID: cds-YP_184872.1 — appears 2 times
#     Line 1170: CDS  5641-5805  strand=-  parent=gene-CcBV_26.4
#     Line 1171: CDS  5281-5553  strand=-  parent=gene-CcBV_26.4
#
#   ID: cds-YP_184875.1 — appears 3 times
#     Line 1187: CDS  11373-11528  strand=-  parent=gene-CcBV_26.7
#     Line 1188: CDS  11071-11319  strand=-  parent=gene-CcBV_26.7
#     Line 1189: CDS  10604-11011  strand=-  parent=gene-CcBV_26.7
#
#   ID: cds-YP_184876.1 — appears 2 times
#     Line 1205: CDS  2593-2638  strand=+  parent=gene-CcBV_30.1
#     Line 1206: CDS  2765-3354  strand=+  parent=gene-CcBV_30.1
#
#   ID: cds-YP_184878.1 — appears 2 times
#     Line 1216: CDS  10335-10411  strand=-  parent=gene-CcBV_30.4
#     Line 1217: CDS  9046-9982  strand=-  parent=gene-CcBV_30.4
#
#   ID: cds-YP_184879.1 — appears 3 times
#     Line 1226: CDS  13633-14164  strand=-  parent=gene-CcBV_30.5
#     Line 1227: CDS  12591-13520  strand=-  parent=gene-CcBV_30.5
#     Line 1228: CDS  11800-12419  strand=-  parent=gene-CcBV_30.5
#
#   ID: cds-YP_184880.1 — appears 3 times
#     Line 1242: CDS  18638-18692  strand=-  parent=gene-CcBV_30.6
#     Line 1243: CDS  16958-18407  strand=-  parent=gene-CcBV_30.6
#     Line 1244: CDS  16372-16882  strand=-  parent=gene-CcBV_30.6
#
#   ID: cds-YP_184881.1 — appears 2 times
#     Line 1255: CDS  30824-30877  strand=-  parent=gene-CcBV_31.9
#     Line 1256: CDS  29753-30601  strand=-  parent=gene-CcBV_31.9
#
#   ID: id-CcBV_31.9 — appears 2 times
#     Line 1259: intron  1-168  strand=-  parent=gene-CcBV_31.9
#     Line 1260: intron  30601-30652  strand=-  parent=gene-CcBV_31.9
#
#   ID: cds-YP_184883.1 — appears 2 times
#     Line 1272: CDS  7184-7829  strand=-  parent=gene-CcBV_31.3
#     Line 1273: CDS  6159-6883  strand=-  parent=gene-CcBV_31.3
#
#   ID: cds-YP_184884.1 — appears 2 times
#     Line 1278: CDS  10092-10149  strand=-  parent=gene-CcBV_31.4
#     Line 1279: CDS  9103-9974  strand=-  parent=gene-CcBV_31.4
#
#   ID: cds-YP_184885.1 — appears 2 times
#     Line 1289: CDS  13735-13791  strand=-  parent=gene-CcBV_31.5
#     Line 1290: CDS  13183-13632  strand=-  parent=gene-CcBV_31.5
#
#   ID: cds-YP_184886.1 — appears 2 times
#     Line 1300: CDS  19008-19179  strand=-  parent=gene-CcBV_31.7
#     Line 1301: CDS  17916-18772  strand=-  parent=gene-CcBV_31.7
#
#   ID: id-CcBV_rt_31.7 — appears 2 times
#     Line 1318: exon  26458-27216  strand=-  parent=gene-CcBV_rt_31.7
#     Line 1319: exon  24680-26440  strand=-  parent=gene-CcBV_rt_31.7
#
#   ID: cds-YP_184889.1 — appears 2 times
#     Line 1333: CDS  4768-5084  strand=+  parent=gene-CcBV_32.2
#     Line 1334: CDS  5264-5396  strand=+  parent=gene-CcBV_32.2
#
#   ID: cds-YP_184890.1 — appears 2 times
#     Line 1337: CDS  6604-6681  strand=-  parent=gene-CcBV_32.3
#     Line 1338: CDS  6281-6520  strand=-  parent=gene-CcBV_32.3
#
#   ID: cds-YP_184891.1 — appears 2 times
#     Line 1350: CDS  13485-13717  strand=-  parent=gene-CcBV_32.4
#     Line 1351: CDS  12811-12883  strand=-  parent=gene-CcBV_32.4
#
#   ID: cds-YP_184893.1 — appears 3 times
#     Line 1371: CDS  20273-20350  strand=-  parent=gene-CcBV_32.7
#     Line 1372: CDS  19584-19776  strand=-  parent=gene-CcBV_32.7
#     Line 1373: CDS  19287-19309  strand=-  parent=gene-CcBV_32.7
#
#   ID: cds-YP_184894.1 — appears 4 times
#     Line 1380: CDS  21335-21603  strand=+  parent=gene-CcBV_32.8
#     Line 1381: CDS  22544-22795  strand=+  parent=gene-CcBV_32.8
#     Line 1382: CDS  22922-23263  strand=+  parent=gene-CcBV_32.8
#     Line 1383: CDS  23601-23790  strand=+  parent=gene-CcBV_32.8
#
#   ID: cds-YP_184895.1 — appears 3 times
#     Line 1392: CDS  27837-28094  strand=-  parent=gene-CcBV_32.9
#     Line 1393: CDS  26287-26519  strand=-  parent=gene-CcBV_32.9
#     Line 1394: CDS  26012-26204  strand=-  parent=gene-CcBV_32.9
#
#   ID: cds-YP_184896.1 — appears 2 times
#     Line 1401: CDS  29367-29565  strand=-  parent=gene-CcBV_32.10
#     Line 1402: CDS  28399-28652  strand=-  parent=gene-CcBV_32.10
#
#   ID: cds-YP_184897.1 — appears 4 times
#     Line 1411: CDS  40609-40683  strand=-  parent=gene-CcBV_32.11
#     Line 1412: CDS  38991-39173  strand=-  parent=gene-CcBV_32.11
#     Line 1413: CDS  37907-38033  strand=-  parent=gene-CcBV_32.11
#     Line 1414: CDS  37214-37380  strand=-  parent=gene-CcBV_32.11
#
#   ID: cds-YP_184899.1 — appears 2 times
#     Line 1433: CDS  258-312  strand=+  parent=gene-CcBV_33.1
#     Line 1434: CDS  514-923  strand=+  parent=gene-CcBV_33.1
#
#   ID: cds-YP_184900.1 — appears 3 times
#     Line 1441: CDS  2342-2591  strand=+  parent=gene-CcBV_33.2
#     Line 1442: CDS  2706-2786  strand=+  parent=gene-CcBV_33.2
#     Line 1443: CDS  2907-4666  strand=+  parent=gene-CcBV_33.2
#
#   ID: cds-YP_184901.1 — appears 3 times
#     Line 1453: CDS  9029-9080  strand=-  parent=gene-CcBV_33.3
#     Line 1454: CDS  8557-8877  strand=-  parent=gene-CcBV_33.3
#     Line 1455: CDS  7797-7882  strand=-  parent=gene-CcBV_33.3
#
#   ID: cds-YP_184902.1 — appears 2 times
#     Line 1468: CDS  14242-14296  strand=-  parent=gene-CcBV_33.4
#     Line 1469: CDS  12608-12894  strand=-  parent=gene-CcBV_33.4
#
#   ID: cds-YP_184904.1 — appears 2 times
#     Line 1479: CDS  19479-19533  strand=-  parent=gene-CcBV_33.6
#     Line 1480: CDS  18984-19312  strand=-  parent=gene-CcBV_33.6
#
#   ID: cds-YP_184906.1 — appears 2 times
#     Line 1492: CDS  2943-3050  strand=+  parent=gene-CcBV_35.2
#     Line 1493: CDS  3521-3823  strand=+  parent=gene-CcBV_35.2
#
#   ID: cds-YP_184907.1 — appears 2 times
#     Line 1510: CDS  919-970  strand=+  parent=gene-CcBV_36.1
#     Line 1511: CDS  1133-1515  strand=+  parent=gene-CcBV_36.1
#
#   ID: cds-YP_184908.1 — appears 4 times
#     Line 1528: CDS  6736-6826  strand=+  parent=gene-CcBV_36.2
#     Line 1529: CDS  7083-7128  strand=+  parent=gene-CcBV_36.2
#     Line 1530: CDS  7209-7627  strand=+  parent=gene-CcBV_36.2
#     Line 1531: CDS  7759-7892  strand=+  parent=gene-CcBV_36.2
#
#   ID: cds-YP_184909.1 — appears 2 times
#     Line 1546: CDS  12371-12449  strand=+  parent=gene-CcBV_36.3
#     Line 1547: CDS  12722-13647  strand=+  parent=gene-CcBV_36.3
#
#   ID: cds-YP_184910.1 — appears 2 times
#     Line 1552: CDS  15532-15583  strand=+  parent=gene-CcBV_36.4
#     Line 1553: CDS  15914-16299  strand=+  parent=gene-CcBV_36.4
#
# ================================================================================
# FILE: ../viral_data_all/ncbi_dataset/data_subset/GCA_002402265.1/genomic.gff
# ================================================================================
#
# Features with DUPLICATE IDs (multi-part/discontinuous locations):
#
#   ID: gene-LMP2 — appears 11 times
#     Line 9: gene  59-1680  strand=+  parent=
#     Line 10: gene  360-458  strand=+  parent=
#     Line 11: gene  540-788  strand=+  parent=
#     Line 12: gene  871-951  strand=+  parent=
#     Line 13: gene  1026-1196  strand=+  parent=
#     Line 14: gene  1280-1495  strand=+  parent=
#     Line 15: gene  1574-1682  strand=+  parent=
#     Line 16: gene  5408-5856  strand=+  parent=
#     Line 17: gene  166103-166458  strand=+  parent=
#     Line 18: gene  58-272  strand=+  parent=
#     Line 19: gene  58-1680  strand=+  parent=
#
#   ID: cds-CAD53382.1 — appears 8 times
#     Line 20: CDS  166103-166458  strand=+  parent=gene-LMP2
#     Line 21: CDS  58-272  strand=+  parent=gene-LMP2
#     Line 22: CDS  360-458  strand=+  parent=gene-LMP2
#     Line 23: CDS  540-788  strand=+  parent=gene-LMP2
#     Line 24: CDS  871-951  strand=+  parent=gene-LMP2
#     Line 25: CDS  1026-1196  strand=+  parent=gene-LMP2
#     Line 26: CDS  1280-1495  strand=+  parent=gene-LMP2
#     Line 27: CDS  1574-1680  strand=+  parent=gene-LMP2
#
#   ID: cds-CAD53383.1 — appears 7 times
#     Line 28: CDS  59-272  strand=+  parent=gene-LMP2
#     Line 29: CDS  360-458  strand=+  parent=gene-LMP2
#     Line 30: CDS  540-788  strand=+  parent=gene-LMP2
#     Line 31: CDS  871-951  strand=+  parent=gene-LMP2
#     Line 32: CDS  1026-1196  strand=+  parent=gene-LMP2
#     Line 33: CDS  1280-1495  strand=+  parent=gene-LMP2
#     Line 34: CDS  1574-1680  strand=+  parent=gene-LMP2
#
#   ID: gene-BNRF1 — appears 2 times
#     Line 44: gene  1691-1695  strand=+  parent=
#     Line 45: gene  1736-5692  strand=+  parent=
#
#   ID: gene-BCRF1 — appears 3 times
#     Line 55: gene  9631-9636  strand=+  parent=
#     Line 56: gene  9675-10187  strand=+  parent=
#     Line 57: gene  10257-10262  strand=+  parent=
#
#   ID: gene-EBNA-LP — appears 24 times
#     Line 70: gene  14352-14352  strand=+  parent=
#     Line 71: gene  14384-14410  strand=+  parent=
#     Line 72: gene  14554-14619  strand=+  parent=
#     Line 73: gene  14701-14832  strand=+  parent=
#     Line 74: gene  17424-17424  strand=+  parent=
#     Line 75: gene  17626-17691  strand=+  parent=
#     Line 76: gene  17773-17904  strand=+  parent=
#     Line 77: gene  20496-20496  strand=+  parent=
#     Line 78: gene  20698-20763  strand=+  parent=
#     Line 79: gene  20845-20976  strand=+  parent=
#     Line 80: gene  23568-23568  strand=+  parent=
#     Line 81: gene  23770-23835  strand=+  parent=
#     Line 82: gene  23917-24048  strand=+  parent=
#     Line 83: gene  26640-26640  strand=+  parent=
#     Line 84: gene  26842-26907  strand=+  parent=
#     Line 85: gene  26989-27120  strand=+  parent=
#     Line 86: gene  29712-29712  strand=+  parent=
#     Line 87: gene  29914-29979  strand=+  parent=
#     Line 88: gene  30061-30192  strand=+  parent=
#     Line 89: gene  32784-32784  strand=+  parent=
#     Line 90: gene  32986-33051  strand=+  parent=
#     Line 91: gene  33133-33264  strand=+  parent=
#     Line 92: gene  35473-35505  strand=+  parent=
#     Line 93: gene  35590-35711  strand=+  parent=
#
#   ID: cds-CAD53387.1 — appears 17 times
#     Line 95: CDS  14409-14410  strand=+  parent=gene-EBNA-LP
#     Line 96: CDS  14559-14619  strand=+  parent=gene-EBNA-LP
#     Line 97: CDS  14701-14832  strand=+  parent=gene-EBNA-LP
#     Line 98: CDS  17626-17691  strand=+  parent=gene-EBNA-LP
#     Line 99: CDS  17773-17904  strand=+  parent=gene-EBNA-LP
#     Line 100: CDS  20698-20763  strand=+  parent=gene-EBNA-LP
#     Line 101: CDS  20845-20976  strand=+  parent=gene-EBNA-LP
#     Line 102: CDS  23770-23835  strand=+  parent=gene-EBNA-LP
#     Line 103: CDS  23917-24048  strand=+  parent=gene-EBNA-LP
#     Line 104: CDS  26842-26907  strand=+  parent=gene-EBNA-LP
#     Line 105: CDS  26989-27120  strand=+  parent=gene-EBNA-LP
#     Line 106: CDS  29914-29979  strand=+  parent=gene-EBNA-LP
#     Line 107: CDS  30061-30192  strand=+  parent=gene-EBNA-LP
#     Line 108: CDS  32986-33051  strand=+  parent=gene-EBNA-LP
#     Line 109: CDS  33133-33264  strand=+  parent=gene-EBNA-LP
#     Line 110: CDS  35473-35505  strand=+  parent=gene-EBNA-LP
#     Line 111: CDS  35590-35694  strand=+  parent=gene-EBNA-LP
#
#   ID: gene-BHLF1 — appears 2 times
#     Line 178: gene  40524-40529  strand=-  parent=
#     Line 179: gene  38024-38029  strand=-  parent=
#
#   ID: gene-BFLF1 — appears 2 times
#     Line 210: gene  46275-46280  strand=-  parent=
#     Line 211: gene  44660-46237  strand=-  parent=
#
#   ID: gene-BFRF3 — appears 3 times
#     Line 223: gene  49056-49061  strand=+  parent=
#     Line 224: gene  49219-49749  strand=+  parent=
#     Line 225: gene  49781-49786  strand=+  parent=
#
#   ID: gene-BPLF1 — appears 3 times
#     Line 229: gene  59899-59904  strand=-  parent=
#     Line 230: gene  49790-59239  strand=-  parent=
#     Line 231: gene  49775-49780  strand=-  parent=
#
#   ID: gene-BMRF2 — appears 3 times
#     Line 267: gene  68491-68496  strand=+  parent=
#     Line 268: gene  68544-68549  strand=+  parent=
#     Line 269: gene  68830-69903  strand=+  parent=
#
#   ID: gene-SM%2C spliced BSLF2+BMLF1 — appears 2 times
#     Line 278: gene  71940-72000  strand=-  parent=
#     Line 279: gene  70455-71833  strand=-  parent=
#
#   ID: cds-CAD53410.1 — appears 2 times
#     Line 280: CDS  71940-72000  strand=-  parent=gene-SM%2C spliced BSLF2+BMLF1
#     Line 281: CDS  70455-71833  strand=-  parent=gene-SM%2C spliced BSLF2+BMLF1
#
#   ID: gene-BSRF1 — appears 3 times
#     Line 291: gene  74594-74599  strand=+  parent=
#     Line 292: gene  74636-75292  strand=+  parent=
#     Line 293: gene  75311-75316  strand=+  parent=
#
#   ID: gene-BLLF3 — appears 2 times
#     Line 299: gene  76226-76231  strand=-  parent=
#     Line 300: gene  75350-76186  strand=-  parent=
#
#   ID: gene-BLRF1 — appears 2 times
#     Line 304: gene  76219-76224  strand=+  parent=
#     Line 305: gene  76259-76567  strand=+  parent=
#
#   ID: gene-BLRF2 — appears 2 times
#     Line 308: gene  76575-76580  strand=+  parent=
#     Line 309: gene  76637-77125  strand=+  parent=
#
#   ID: gene-BLLF2 — appears 2 times
#     Line 318: gene  77758-77763  strand=-  parent=
#     Line 319: gene  77279-77725  strand=-  parent=
#
#   ID: cds-CAD53419.1 — appears 2 times
#     Line 330: CDS  79955-80293  strand=+  parent=rna-AJ507799.2:79950..82960
#     Line 331: CDS  80382-82877  strand=+  parent=rna-AJ507799.2:79950..82960
#
#   ID: gene-EBNA3B — appears 2 times
#     Line 346: gene  83065-83421  strand=+  parent=
#     Line 347: gene  83500-89502  strand=+  parent=
#
#   ID: cds-CAD53420.1 — appears 2 times
#     Line 351: CDS  83065-83421  strand=+  parent=rna-EBNA3B
#     Line 352: CDS  83500-85959  strand=+  parent=rna-EBNA3B
#
#   ID: gene-EBNA3C — appears 2 times
#     Line 357: gene  86076-86442  strand=+  parent=
#     Line 358: gene  86517-89502  strand=+  parent=
#
#   ID: cds-CAD53421.1 — appears 2 times
#     Line 362: CDS  86083-86442  strand=+  parent=rna-EBNA3C
#     Line 363: CDS  86517-89135  strand=+  parent=rna-EBNA3C
#
#   ID: gene-BZLF2 — appears 2 times
#     Line 372: gene  89867-89872  strand=-  parent=
#     Line 373: gene  89157-89828  strand=-  parent=
#
#   ID: gene-BRLF1 — appears 4 times
#     Line 379: gene  93838-93893  strand=-  parent=
#     Line 380: gene  90367-92897  strand=-  parent=
#     Line 381: gene  90138-90242  strand=-  parent=
#     Line 382: gene  89838-90053  strand=-  parent=
#
#   ID: gene-BZLF1 — appears 3 times
#     Line 390: gene  90367-90906  strand=-  parent=
#     Line 391: gene  90138-90242  strand=-  parent=
#     Line 392: gene  89838-90053  strand=-  parent=
#
#   ID: cds-CAD53423.1 — appears 3 times
#     Line 397: CDS  90367-90867  strand=-  parent=rna-BZLF1
#     Line 398: CDS  90138-90242  strand=-  parent=rna-BZLF1
#     Line 399: CDS  89922-90053  strand=-  parent=rna-BZLF1
#
#   ID: gene-BRRF1 — appears 2 times
#     Line 408: gene  92728-92733  strand=+  parent=
#     Line 409: gene  92894-93827  strand=+  parent=
#
#   ID: gene-BRRF2 — appears 2 times
#     Line 415: gene  93955-93960  strand=+  parent=
#     Line 416: gene  94014-95627  strand=+  parent=
#
#   ID: gene-BKRF3 — appears 2 times
#     Line 433: gene  98065-98832  strand=+  parent=
#     Line 434: gene  99431-99436  strand=+  parent=
#
#   ID: gene-BBLF2-BBLF3 — appears 3 times
#     Line 449: gene  105227-106792  strand=-  parent=
#     Line 450: gene  104493-105098  strand=-  parent=
#     Line 451: gene  104408-104408  strand=-  parent=
#
#   ID: cds-CAD53434.1 — appears 2 times
#     Line 452: CDS  105227-106792  strand=-  parent=gene-BBLF2-BBLF3
#     Line 453: CDS  104493-105098  strand=-  parent=gene-BBLF2-BBLF3
#
#   ID: gene-BBRF3 — appears 4 times
#     Line 458: gene  106693-106698  strand=+  parent=
#     Line 459: gene  106810-106815  strand=+  parent=
#     Line 460: gene  106849-108066  strand=+  parent=
#     Line 461: gene  108070-108075  strand=+  parent=
#
#   ID: cds-CAD53440.1 — appears 2 times
#     Line 482: CDS  112650-113585  strand=+  parent=
#     Line 483: CDS  116927-118063  strand=+  parent=
#
#   ID: gene-BGLF2 — appears 4 times
#     Line 486: gene  114944-114949  strand=-  parent=
#     Line 487: gene  114636-114641  strand=-  parent=
#     Line 488: gene  113575-114585  strand=-  parent=
#     Line 489: gene  113196-113201  strand=-  parent=
#
#   ID: gene-BDLF4-2 — appears 2 times
#     Line 502: gene  117086-117091  strand=-  parent=
#     Line 503: gene  116761-116766  strand=-  parent=
#
#   ID: gene-BDLF3 — appears 3 times
#     Line 509: gene  118811-118816  strand=-  parent=
#     Line 510: gene  118074-118778  strand=-  parent=
#     Line 511: gene  118066-118071  strand=-  parent=
#
#   ID: gene-BDLF2 — appears 2 times
#     Line 515: gene  120183-120188  strand=-  parent=
#     Line 516: gene  118839-120101  strand=-  parent=
#
#   ID: gene-BDLF1-2 — appears 2 times
#     Line 527: gene  121093-121098  strand=-  parent=
#     Line 528: gene  121059-121064  strand=-  parent=
#
#   ID: gene-BXLF2 — appears 3 times
#     Line 539: gene  131016-131021  strand=-  parent=
#     Line 540: gene  128627-130747  strand=-  parent=
#     Line 541: gene  128608-128613  strand=-  parent=
#
#   ID: gene-BVRF1 — appears 3 times
#     Line 557: gene  133013-133017  strand=+  parent=
#     Line 558: gene  133127-134839  strand=+  parent=
#     Line 559: gene  134881-134886  strand=+  parent=
#
#   ID: gene-BdRF1 — appears 2 times
#     Line 570: gene  136331-136336  strand=+  parent=
#     Line 571: gene  136418-137455  strand=+  parent=
#
#   ID: gene-BILF2 — appears 3 times
#     Line 576: gene  138277-138282  strand=-  parent=
#     Line 577: gene  137490-138236  strand=-  parent=
#     Line 578: gene  137464-137469  strand=-  parent=
#
#   ID: gene-RPMS1 — appears 7 times
#     Line 582: gene  138352-138480  strand=+  parent=
#     Line 583: gene  149581-149712  strand=+  parent=
#     Line 584: gene  149923-150077  strand=+  parent=
#     Line 585: gene  150237-150348  strand=+  parent=
#     Line 586: gene  155267-156737  strand=+  parent=
#     Line 587: gene  156846-156928  strand=+  parent=
#     Line 588: gene  158625-160531  strand=+  parent=
#
#   ID: cds-CAD53460.1 — appears 2 times
#     Line 597: CDS  150323-150348  strand=+  parent=rna-RPMS1
#     Line 598: CDS  155267-155552  strand=+  parent=rna-RPMS1
#
#   ID: gene-A73 — appears 4 times
#     Line 627: gene  155549-156737  strand=+  parent=
#     Line 628: gene  156846-156928  strand=+  parent=
#     Line 629: gene  158625-158751  strand=+  parent=
#     Line 630: gene  159781-160531  strand=+  parent=
#
#   ID: cds-CAD53464.1 — appears 4 times
#     Line 636: CDS  156652-156737  strand=+  parent=rna-A73
#     Line 637: CDS  156846-156928  strand=+  parent=rna-A73
#     Line 638: CDS  158625-158751  strand=+  parent=rna-A73
#     Line 639: CDS  159781-159865  strand=+  parent=rna-A73
#
#   ID: gene-BALF4 — appears 3 times
#     Line 640: gene  158907-158912  strand=-  parent=
#     Line 641: gene  156291-158864  strand=-  parent=
#     Line 642: gene  156244-156249  strand=-  parent=
#
#   ID: gene-BALF2 — appears 3 times
#     Line 652: gene  164351-164356  strand=-  parent=
#     Line 653: gene  160926-164312  strand=-  parent=
#     Line 654: gene  160550-160555  strand=-  parent=
#
#   ID: gene-BALF1 — appears 3 times
#     Line 659: gene  165250-165255  strand=-  parent=
#     Line 660: gene  164397-165059  strand=-  parent=
#     Line 661: gene  164388-164393  strand=-  parent=
#
#   ID: gene-BARF1 — appears 2 times
#     Line 667: gene  165008-165013  strand=+  parent=
#     Line 668: gene  165046-165712  strand=+  parent=
#
#   ID: gene-LMP2A — appears 2 times
#     Line 672: gene  166011-166016  strand=+  parent=
#     Line 673: gene  166040-166458  strand=+  parent=
#
#   ID: gene-LMP1 — appears 5 times
#     Line 677: gene  168749-169055  strand=-  parent=
#     Line 678: gene  168671-168748  strand=-  parent=
#     Line 679: gene  168584-168670  strand=-  parent=
#     Line 680: gene  168508-168583  strand=-  parent=
#     Line 681: gene  166461-168507  strand=-  parent=
#
#   ID: cds-CAD53472.1 — appears 3 times
#     Line 682: CDS  168749-169016  strand=-  parent=gene-LMP1
#     Line 683: CDS  168584-168670  strand=-  parent=gene-LMP1
#     Line 684: CDS  167702-168507  strand=-  parent=gene-LMP1
#
# ================================================================================
# FILE: ../viral_data_all/ncbi_dataset/data_subset/GCF_000850265.1/genomic.gff
# ================================================================================
#
# Features with DUPLICATE IDs (multi-part/discontinuous locations):
#
#   ID: gene-WDSVgp2 — appears 2 times
#     Line 13: gene  1-246  strand=+  parent=
#     Line 14: gene  5856-12708  strand=+  parent=
#
# ================================================================================
# FILE: ../viral_data_all/ncbi_dataset/data_subset/GCA_003071505.1/genomic.gff
# ================================================================================
#
# Features with DUPLICATE IDs (multi-part/discontinuous locations):
#
#   ID: id-EhV014-2 — appears 6 times
#     Line 26: sequence_feature  1534-1602  strand=+  parent=
#     Line 27: sequence_feature  1657-1719  strand=+  parent=
#     Line 28: sequence_feature  1762-1824  strand=+  parent=
#     Line 29: sequence_feature  1879-1941  strand=+  parent=
#     Line 30: sequence_feature  2038-2100  strand=+  parent=
#     Line 31: sequence_feature  2215-2277  strand=+  parent=
#
#   ID: id-EhV016 — appears 2 times
#     Line 38: sequence_feature  2539-2601  strand=+  parent=
#     Line 39: sequence_feature  2641-2697  strand=+  parent=
#
#   ID: id-EhV018-3 — appears 5 times
#     Line 46: sequence_feature  6036-6080  strand=-  parent=
#     Line 47: sequence_feature  5859-5918  strand=-  parent=
#     Line 48: sequence_feature  5682-5735  strand=-  parent=
#     Line 49: sequence_feature  5610-5672  strand=-  parent=
#     Line 50: sequence_feature  5454-5501  strand=-  parent=
#
#   ID: id-EhV020-2 — appears 6 times
#     Line 62: sequence_feature  8648-8707  strand=-  parent=
#     Line 63: sequence_feature  8579-8635  strand=-  parent=
#     Line 64: sequence_feature  8495-8569  strand=-  parent=
#     Line 65: sequence_feature  8342-8410  strand=-  parent=
#     Line 66: sequence_feature  8075-8119  strand=-  parent=
#     Line 67: sequence_feature  7955-8008  strand=-  parent=
#
#   ID: id-EhV021 — appears 2 times
#     Line 77: sequence_feature  8792-8854  strand=+  parent=
#     Line 78: sequence_feature  9782-9844  strand=+  parent=
#
#   ID: id-EhV021-8 — appears 3 times
#     Line 85: sequence_feature  9002-9049  strand=+  parent=
#     Line 86: sequence_feature  9176-9220  strand=+  parent=
#     Line 87: sequence_feature  9500-9538  strand=+  parent=
#
#   ID: id-EhV025 — appears 2 times
#     Line 104: sequence_feature  14426-14488  strand=-  parent=
#     Line 105: sequence_feature  14318-14386  strand=-  parent=
#
#   ID: id-EhV029 — appears 5 times
#     Line 123: sequence_feature  18302-18364  strand=-  parent=
#     Line 124: sequence_feature  18212-18274  strand=-  parent=
#     Line 125: sequence_feature  18122-18184  strand=-  parent=
#     Line 126: sequence_feature  18029-18097  strand=-  parent=
#     Line 127: sequence_feature  17939-18001  strand=-  parent=
#
#   ID: id-EhV030-7 — appears 3 times
#     Line 136: sequence_feature  20074-20115  strand=+  parent=
#     Line 137: sequence_feature  20347-20385  strand=+  parent=
#     Line 138: sequence_feature  20518-20544  strand=+  parent=
#
#   ID: id-EhV031 — appears 6 times
#     Line 142: sequence_feature  21533-21580  strand=+  parent=
#     Line 143: sequence_feature  21635-21697  strand=+  parent=
#     Line 144: sequence_feature  21758-21820  strand=+  parent=
#     Line 145: sequence_feature  21941-22003  strand=+  parent=
#     Line 146: sequence_feature  22064-22120  strand=+  parent=
#     Line 147: sequence_feature  22262-22324  strand=+  parent=
#
#   ID: id-EhV032 — appears 6 times
#     Line 154: sequence_feature  23015-23071  strand=-  parent=
#     Line 155: sequence_feature  22937-22999  strand=-  parent=
#     Line 156: sequence_feature  22862-22924  strand=-  parent=
#     Line 157: sequence_feature  22751-22807  strand=-  parent=
#     Line 158: sequence_feature  22628-22690  strand=-  parent=
#     Line 159: sequence_feature  22538-22600  strand=-  parent=
#
#   ID: id-EhV033 — appears 5 times
#     Line 164: sequence_feature  23590-23646  strand=-  parent=
#     Line 165: sequence_feature  23515-23577  strand=-  parent=
#     Line 166: sequence_feature  23293-23355  strand=-  parent=
#     Line 167: sequence_feature  23203-23265  strand=-  parent=
#     Line 168: sequence_feature  23113-23175  strand=-  parent=
#
#   ID: id-EhV035 — appears 2 times
#     Line 173: sequence_feature  27586-27648  strand=-  parent=
#     Line 174: sequence_feature  23716-23784  strand=-  parent=
#
#   ID: gene-tRNA-Leu — appears 2 times
#     Line 196: gene  31602-31642  strand=-  parent=
#     Line 197: gene  31538-31581  strand=-  parent=
#
#   ID: gene-tRNA-Ile — appears 2 times
#     Line 202: gene  31722-31761  strand=-  parent=
#     Line 203: gene  31664-31699  strand=-  parent=
#
#   ID: id-EhV050 — appears 2 times
#     Line 240: sequence_feature  38159-39346  strand=-  parent=
#     Line 241: sequence_feature  36977-38134  strand=-  parent=
#
#   ID: id-EhV050-2 — appears 2 times
#     Line 242: sequence_feature  38456-39175  strand=-  parent=
#     Line 243: sequence_feature  37250-37972  strand=-  parent=
#
#   ID: id-EhV050-3 — appears 2 times
#     Line 244: sequence_feature  38168-39226  strand=-  parent=
#     Line 245: sequence_feature  37259-37972  strand=-  parent=
#
#   ID: id-EhV055 — appears 6 times
#     Line 262: sequence_feature  43170-43232  strand=-  parent=
#     Line 263: sequence_feature  43017-43079  strand=-  parent=
#     Line 264: sequence_feature  42804-42866  strand=-  parent=
#     Line 265: sequence_feature  42672-42734  strand=-  parent=
#     Line 266: sequence_feature  42597-42659  strand=-  parent=
#     Line 267: sequence_feature  42480-42542  strand=-  parent=
#
#   ID: id-EhV060-6 — appears 3 times
#     Line 294: sequence_feature  53510-53599  strand=-  parent=
#     Line 295: sequence_feature  52661-52783  strand=-  parent=
#     Line 296: sequence_feature  52067-52168  strand=-  parent=
#
#   ID: id-EhV060-7 — appears 3 times
#     Line 297: sequence_feature  53612-53650  strand=-  parent=
#     Line 298: sequence_feature  53549-53614  strand=-  parent=
#     Line 299: sequence_feature  53501-53551  strand=-  parent=
#
#   ID: id-EhV062 — appears 2 times
#     Line 312: sequence_feature  55332-55394  strand=+  parent=
#     Line 313: sequence_feature  55563-55631  strand=+  parent=
#
#   ID: cds-CAZ69400.1 — appears 2 times
#     Line 319: CDS  57661-60810  strand=-  parent=gene-EhV064
#     Line 320: CDS  56333-57589  strand=-  parent=gene-EhV064
#
#   ID: id-EhV064-2 — appears 3 times
#     Line 322: sequence_feature  60016-60777  strand=-  parent=
#     Line 323: sequence_feature  57661-59910  strand=-  parent=
#     Line 324: sequence_feature  56495-57589  strand=-  parent=
#
#   ID: id-EhV064-3 — appears 2 times
#     Line 325: sequence_feature  57661-58335  strand=-  parent=
#     Line 326: sequence_feature  56639-57589  strand=-  parent=
#
#   ID: id-EhV066 — appears 3 times
#     Line 340: sequence_feature  61540-61602  strand=+  parent=
#     Line 341: sequence_feature  61657-61719  strand=+  parent=
#     Line 342: sequence_feature  61762-61818  strand=+  parent=
#
#   ID: id-EhV069 — appears 2 times
#     Line 351: sequence_feature  65410-65472  strand=+  parent=
#     Line 352: sequence_feature  65488-65550  strand=+  parent=
#
#   ID: id-EhV074 — appears 2 times
#     Line 365: sequence_feature  69202-69270  strand=-  parent=
#     Line 366: sequence_feature  68959-69021  strand=-  parent=
#
#   ID: id-EhV077-3 — appears 7 times
#     Line 379: sequence_feature  71321-71383  strand=-  parent=
#     Line 380: sequence_feature  71198-71260  strand=-  parent=
#     Line 381: sequence_feature  71081-71143  strand=-  parent=
#     Line 382: sequence_feature  70958-71020  strand=-  parent=
#     Line 383: sequence_feature  70886-70948  strand=-  parent=
#     Line 384: sequence_feature  70763-70825  strand=-  parent=
#     Line 385: sequence_feature  70679-70747  strand=-  parent=
#
#   ID: id-EhV078 — appears 7 times
#     Line 391: sequence_feature  71673-71735  strand=+  parent=
#     Line 392: sequence_feature  71838-71900  strand=+  parent=
#     Line 393: sequence_feature  71961-72017  strand=+  parent=
# ...
#
#   ID: gene-CcBV_18.9 — appears 5 times
#     Line 921: gene  30006-30282  strand=+  parent=
#     Line 922: gene  30283-30363  strand=+  parent=
#     Line 923: gene  30364-30452  strand=+  parent=
#     Line 924: gene  30453-30520  strand=+  parent=
#     Line 925: gene  30521-30565  strand=+  parent=
#
#   ID: cds-CAG17467.1 — appears 3 times
#     Line 926: CDS  30006-30282  strand=+  parent=gene-CcBV_18.9
#     Line 927: CDS  30364-30452  strand=+  parent=gene-CcBV_18.9
#     Line 928: CDS  30521-30565  strand=+  parent=gene-CcBV_18.9
#
#   ID: gene-CcBV_18.1 — appears 3 times
#     Line 936: gene  31901-32021  strand=+  parent=
#     Line 937: gene  32022-32138  strand=+  parent=
#     Line 938: gene  31-620  strand=+  parent=
#
#   ID: cds-CAG17459.1 — appears 2 times
#     Line 939: CDS  31901-32021  strand=+  parent=gene-CcBV_18.1
#     Line 940: CDS  31-620  strand=+  parent=gene-CcBV_18.1
#
#   ID: cds-CAG17469.1 — appears 2 times
#     Line 950: CDS  1776-1827  strand=+  parent=gene-CcBV_19.3
#     Line 951: CDS  1913-2916  strand=+  parent=gene-CcBV_19.3
#
#   ID: cds-CAG17470.1 — appears 3 times
#     Line 956: CDS  3605-3659  strand=+  parent=gene-CcBV_19.4
#     Line 957: CDS  3853-3936  strand=+  parent=gene-CcBV_19.4
#     Line 958: CDS  4383-5041  strand=+  parent=gene-CcBV_19.4
#
#   ID: cds-CAG17472.1 — appears 2 times
#     Line 974: CDS  8311-8362  strand=+  parent=gene-CcBV_19.1
#     Line 975: CDS  8448-9433  strand=+  parent=gene-CcBV_19.1
#
#   ID: cds-CAG17474.1 — appears 3 times
#     Line 982: CDS  875-925  strand=+  parent=gene-CcBV_20.1
#     Line 983: CDS  1051-1120  strand=+  parent=gene-CcBV_20.1
#     Line 984: CDS  1161-2035  strand=+  parent=gene-CcBV_20.1
#
#   ID: cds-CAG17475.1 — appears 3 times
#     Line 998: CDS  8119-8368  strand=+  parent=gene-CcBV_20.2
#     Line 999: CDS  8483-8563  strand=+  parent=gene-CcBV_20.2
#     Line 1000: CDS  8685-11629  strand=+  parent=gene-CcBV_20.2
#
#   ID: cds-CAG17476.1 — appears 2 times
#     Line 1047: CDS  9256-9307  strand=-  parent=gene-CcBV_22.2
#     Line 1048: CDS  8711-9093  strand=-  parent=gene-CcBV_22.2
#
#   ID: cds-CAG17477.1 — appears 2 times
#     Line 1054: CDS  12121-12172  strand=-  parent=gene-CcBV_22.3
#     Line 1055: CDS  11405-11790  strand=-  parent=gene-CcBV_22.3
#
#   ID: cds-CAG17478.1 — appears 2 times
#     Line 1061: CDS  12525-12576  strand=+  parent=gene-CcBV_22.4
#     Line 1062: CDS  12915-14527  strand=+  parent=gene-CcBV_22.4
#
#   ID: cds-CAG17480.1 — appears 2 times
#     Line 1085: CDS  24594-24672  strand=-  parent=gene-CcBV_22.6
#     Line 1086: CDS  23396-24321  strand=-  parent=gene-CcBV_22.6
#
#   ID: cds-CAG17481.1 — appears 5 times
#     Line 1097: CDS  1167-1273  strand=+  parent=gene-CcBV_23.1
#     Line 1098: CDS  1507-1535  strand=+  parent=gene-CcBV_23.1
#     Line 1099: CDS  1704-1901  strand=+  parent=gene-CcBV_23.1
#     Line 1100: CDS  2017-2097  strand=+  parent=gene-CcBV_23.1
#     Line 1101: CDS  2218-4535  strand=+  parent=gene-CcBV_23.1
#
#   ID: cds-CAG17482.1 — appears 5 times
#     Line 1112: CDS  8313-8364  strand=-  parent=gene-CcBV_23.2
#     Line 1113: CDS  7779-8228  strand=-  parent=gene-CcBV_23.2
#     Line 1114: CDS  7558-7668  strand=-  parent=gene-CcBV_23.2
#     Line 1115: CDS  6906-7082  strand=-  parent=gene-CcBV_23.2
#     Line 1116: CDS  6289-6395  strand=-  parent=gene-CcBV_23.2
#
#   ID: cds-CAG17483.1 — appears 2 times
#     Line 1130: CDS  9786-9840  strand=-  parent=gene-CcBV_23.3
#     Line 1131: CDS  9318-9556  strand=-  parent=gene-CcBV_23.3
#
#   ID: cds-CAG17484.1 — appears 3 times
#     Line 1136: CDS  10227-10336  strand=+  parent=gene-CcBV_23.4
#     Line 1137: CDS  10434-11766  strand=+  parent=gene-CcBV_23.4
#     Line 1138: CDS  11852-11992  strand=+  parent=gene-CcBV_23.4
#
#   ID: cds-CAG17485.1 — appears 2 times
#     Line 1151: CDS  728-979  strand=+  parent=gene-CcBV_25.1
#     Line 1152: CDS  1094-1186  strand=+  parent=gene-CcBV_25.1
#
#   ID: cds-CAG17487.1 — appears 2 times
#     Line 1166: CDS  7907-7958  strand=-  parent=gene-CcBV_25.3
#     Line 1167: CDS  6836-7821  strand=-  parent=gene-CcBV_25.3
#
#   ID: cds-CAG17488.1 — appears 2 times
#     Line 1172: CDS  8724-9134  strand=+  parent=gene-CcBV_25.4
#     Line 1173: CDS  9234-9374  strand=+  parent=gene-CcBV_25.4
#
#   ID: cds-CAG17489.1 — appears 2 times
#     Line 1180: CDS  10634-10676  strand=-  parent=gene-CcBV_25.5
#     Line 1181: CDS  10161-10438  strand=-  parent=gene-CcBV_25.5
#
#   ID: cds-CAG17490.1 — appears 4 times
#     Line 1186: CDS  10915-10939  strand=+  parent=gene-CcBV_25.6
#     Line 1187: CDS  12519-12671  strand=+  parent=gene-CcBV_25.6
#     Line 1188: CDS  12759-13200  strand=+  parent=gene-CcBV_25.6
#     Line 1189: CDS  13272-13806  strand=+  parent=gene-CcBV_25.6
#
#   ID: cds-CAG17492.1 — appears 2 times
#     Line 1211: CDS  1825-1967  strand=+  parent=gene-CcBV_26.2
#     Line 1212: CDS  1991-2294  strand=+  parent=gene-CcBV_26.2
#
#   ID: cds-CAG17493.1 — appears 2 times
#     Line 1218: CDS  3370-3510  strand=+  parent=gene-CcBV_26.3
#     Line 1219: CDS  4293-4859  strand=+  parent=gene-CcBV_26.3
#
#   ID: cds-CAG17494.1 — appears 2 times
#     Line 1228: CDS  5641-5805  strand=-  parent=gene-CcBV_26.4
#     Line 1229: CDS  5281-5553  strand=-  parent=gene-CcBV_26.4
#
#   ID: cds-CAG17497.1 — appears 3 times
#     Line 1245: CDS  11373-11528  strand=-  parent=gene-CcBV_26.7
#     Line 1246: CDS  11071-11319  strand=-  parent=gene-CcBV_26.7
#     Line 1247: CDS  10604-11011  strand=-  parent=gene-CcBV_26.7
#
#   ID: cds-CAG17498.1 — appears 2 times
#     Line 1263: CDS  2593-2638  strand=+  parent=gene-CcBV_30.1
#     Line 1264: CDS  2765-3354  strand=+  parent=gene-CcBV_30.1
#
#   ID: cds-CAG17500.1 — appears 2 times
#     Line 1274: CDS  10335-10411  strand=-  parent=gene-CcBV_30.4
#     Line 1275: CDS  9046-9982  strand=-  parent=gene-CcBV_30.4
#
#   ID: cds-CAG17501.1 — appears 3 times
#     Line 1284: CDS  13633-14164  strand=-  parent=gene-CcBV_30.5
#     Line 1285: CDS  12591-13520  strand=-  parent=gene-CcBV_30.5
#     Line 1286: CDS  11800-12419  strand=-  parent=gene-CcBV_30.5
#
#   ID: cds-CAG17502.1 — appears 3 times
#     Line 1300: CDS  18638-18692  strand=-  parent=gene-CcBV_30.6
#     Line 1301: CDS  16958-18407  strand=-  parent=gene-CcBV_30.6
#     Line 1302: CDS  16372-16882  strand=-  parent=gene-CcBV_30.6
#
#   ID: cds-CcBV_31.1 — appears 3 times
#     Line 1315: CDS  1730-2263  strand=+  parent=gene-CcBV_31.1
#     Line 1316: CDS  2282-2716  strand=+  parent=gene-CcBV_31.1
#     Line 1317: CDS  2731-5106  strand=+  parent=gene-CcBV_31.1
#
#   ID: gene-CcBV_31.3 — appears 3 times
#     Line 1320: gene  7184-7829  strand=-  parent=
#     Line 1321: gene  6884-7183  strand=-  parent=
#     Line 1322: gene  6159-6883  strand=-  parent=
#
#   ID: cds-CAG18160.1 — appears 2 times
#     Line 1323: CDS  7184-7829  strand=-  parent=gene-CcBV_31.3
#     Line 1324: CDS  6159-6883  strand=-  parent=gene-CcBV_31.3
#
#   ID: gene-CcBV_31.4 — appears 3 times
#     Line 1328: gene  10092-10149  strand=-  parent=
#     Line 1329: gene  9975-10091  strand=-  parent=
#     Line 1330: gene  9103-9974  strand=-  parent=
#
#   ID: cds-CAG18161.1 — appears 2 times
#     Line 1331: CDS  10092-10149  strand=-  parent=gene-CcBV_31.4
#     Line 1332: CDS  9103-9974  strand=-  parent=gene-CcBV_31.4
#
#   ID: gene-CcBV_31.5 — appears 3 times
#     Line 1341: gene  13735-13791  strand=-  parent=
#     Line 1342: gene  13645-13734  strand=-  parent=
#     Line 1343: gene  13183-13644  strand=-  parent=
#
#   ID: cds-CAG18162.1 — appears 2 times
#     Line 1344: CDS  13735-13791  strand=-  parent=gene-CcBV_31.5
#     Line 1345: CDS  13183-13632  strand=-  parent=gene-CcBV_31.5
#
#   ID: gene-CcBV_31.7 — appears 3 times
#     Line 1355: gene  19008-19179  strand=-  parent=
#     Line 1356: gene  18773-19007  strand=-  parent=
#     Line 1357: gene  17916-18772  strand=-  parent=
#
#   ID: cds-CAG18163.1 — appears 2 times
#     Line 1358: CDS  19008-19179  strand=-  parent=gene-CcBV_31.7
#     Line 1359: CDS  17916-18772  strand=-  parent=gene-CcBV_31.7
#
#   ID: gene-CcBV_rt_31.7 — appears 2 times
#     Line 1377: gene  26458-27216  strand=-  parent=
#     Line 1378: gene  24680-26440  strand=-  parent=
#
#   ID: id-CcBV_rt_31.7 — appears 2 times
#     Line 1379: exon  26458-27216  strand=-  parent=gene-CcBV_rt_31.7
#     Line 1380: exon  24680-26440  strand=-  parent=gene-CcBV_rt_31.7
#
#   ID: gene-CcBV_31.9 — appears 4 times
#     Line 1389: gene  169-222  strand=-  parent=
#     Line 1390: gene  1-168  strand=-  parent=
#     Line 1391: gene  30601-30652  strand=-  parent=
#     Line 1392: gene  29753-30601  strand=-  parent=
#
#   ID: cds-CAG24028.1 — appears 2 times
#     Line 1393: CDS  30824-30877  strand=-  parent=gene-CcBV_31.9
#     Line 1394: CDS  29753-30601  strand=-  parent=gene-CcBV_31.9
#
#   ID: id-CcBV_31.9 — appears 2 times
#     Line 1397: intron  1-168  strand=-  parent=gene-CcBV_31.9
#     Line 1398: intron  30601-30652  strand=-  parent=gene-CcBV_31.9
#
#   ID: cds-CAG18433.1 — appears 2 times
#     Line 1405: CDS  4768-5084  strand=+  parent=gene-CcBV_32.2
#     Line 1406: CDS  5264-5396  strand=+  parent=gene-CcBV_32.2
#
#   ID: cds-CAG18434.1 — appears 2 times
#     Line 1409: CDS  6604-6681  strand=-  parent=gene-CcBV_32.3
#     Line 1410: CDS  6281-6520  strand=-  parent=gene-CcBV_32.3
#
#   ID: cds-CAG18435.1 — appears 2 times
#     Line 1422: CDS  13485-13717  strand=-  parent=gene-CcBV_32.4
#     Line 1423: CDS  12811-12883  strand=-  parent=gene-CcBV_32.4
#
#   ID: cds-CAG18437.1 — appears 3 times
#     Line 1443: CDS  20273-20350  strand=-  parent=gene-CcBV_32.7
#     Line 1444: CDS  19584-19776  strand=-  parent=gene-CcBV_32.7
#     Line 1445: CDS  19287-19309  strand=-  parent=gene-CcBV_32.7
#
#   ID: cds-CAG18438.1 — appears 4 times
#     Line 1452: CDS  21335-21603  strand=+  parent=gene-CcBV_32.8
#     Line 1453: CDS  22544-22795  strand=+  parent=gene-CcBV_32.8
#     Line 1454: CDS  22922-23263  strand=+  parent=gene-CcBV_32.8
#     Line 1455: CDS  23601-23790  strand=+  parent=gene-CcBV_32.8
#
#   ID: cds-CAG18439.1 — appears 3 times
#     Line 1464: CDS  27837-28094  strand=-  parent=gene-CcBV_32.9
#     Line 1465: CDS  26287-26519  strand=-  parent=gene-CcBV_32.9
#     Line 1466: CDS  26012-26204  strand=-  parent=gene-CcBV_32.9
#
#   ID: cds-CAG18440.1 — appears 2 times
#     Line 1473: CDS  29367-29565  strand=-  parent=gene-CcBV_32.10
#     Line 1474: CDS  28399-28652  strand=-  parent=gene-CcBV_32.10
#
#   ID: cds-CAG18441.1 — appears 4 times
#     Line 1483: CDS  40609-40683  strand=-  parent=gene-CcBV_32.11
#     Line 1484: CDS  38991-39173  strand=-  parent=gene-CcBV_32.11
#     Line 1485: CDS  37907-38033  strand=-  parent=gene-CcBV_32.11
#     Line 1486: CDS  37214-37380  strand=-  parent=gene-CcBV_32.11
#
#   ID: cds-CAG18165.1 — appears 2 times
#     Line 1505: CDS  258-312  strand=+  parent=gene-CcBV_33.1
#     Line 1506: CDS  514-923  strand=+  parent=gene-CcBV_33.1
#
#   ID: cds-CAG18166.1 — appears 3 times
#     Line 1513: CDS  2342-2591  strand=+  parent=gene-CcBV_33.2
#     Line 1514: CDS  2706-2786  strand=+  parent=gene-CcBV_33.2
#     Line 1515: CDS  2907-4666  strand=+  parent=gene-CcBV_33.2
#
#   ID: cds-CAG18167.1 — appears 3 times
#     Line 1525: CDS  9029-9080  strand=-  parent=gene-CcBV_33.3
#     Line 1526: CDS  8557-8877  strand=-  parent=gene-CcBV_33.3
#     Line 1527: CDS  7797-7882  strand=-  parent=gene-CcBV_33.3
#
#   ID: cds-CAG18168.1 — appears 2 times
#     Line 1540: CDS  14242-14296  strand=-  parent=gene-CcBV_33.4
#     Line 1541: CDS  12608-12894  strand=-  parent=gene-CcBV_33.4
#
#   ID: cds-CAG18170.1 — appears 2 times
#     Line 1551: CDS  19479-19533  strand=-  parent=gene-CcBV_33.6
#     Line 1552: CDS  18984-19312  strand=-  parent=gene-CcBV_33.6
#
#   ID: cds-CAG18172.1 — appears 2 times
#     Line 1564: CDS  2943-3050  strand=+  parent=gene-CcBV_35.2
#     Line 1565: CDS  3521-3823  strand=+  parent=gene-CcBV_35.2
#
#   ID: cds-CAG17503.1 — appears 2 times
#     Line 1582: CDS  919-970  strand=+  parent=gene-CcBV_36.1
#     Line 1583: CDS  1133-1515  strand=+  parent=gene-CcBV_36.1
#
#   ID: cds-CAG17504.1 — appears 4 times
#     Line 1600: CDS  6736-6826  strand=+  parent=gene-CcBV_36.2
#     Line 1601: CDS  7083-7128  strand=+  parent=gene-CcBV_36.2
#     Line 1602: CDS  7209-7627  strand=+  parent=gene-CcBV_36.2
#     Line 1603: CDS  7759-7892  strand=+  parent=gene-CcBV_36.2
#
#   ID: cds-CAG17505.1 — appears 2 times
#     Line 1618: CDS  12371-12449  strand=+  parent=gene-CcBV_36.3
#     Line 1619: CDS  12722-13647  strand=+  parent=gene-CcBV_36.3
#
#   ID: cds-CAG17506.1 — appears 2 times
#     Line 1624: CDS  15532-15583  strand=+  parent=gene-CcBV_36.4
#     Line 1625: CDS  15914-16299  strand=+  parent=gene-CcBV_36.4
#
# ================================================================================
# FILE: ../viral_data_all/ncbi_dataset/data_subset/GCA_000857425.1/genomic.gff
# ================================================================================
#
# Features with DUPLICATE IDs (multi-part/discontinuous locations):
#
#   ID: gene-pol — appears 2 times
#     Line 9: gene  1-57  strand=+  parent=
#     Line 10: gene  1571-10479  strand=+  parent=
#
#   ID: gene-env — appears 2 times
#     Line 16: gene  1-57  strand=+  parent=
#     Line 17: gene  4965-10479  strand=+  parent=
#
#   ID: gene-bel 1 / tas — appears 2 times
#     Line 25: gene  7925-8036  strand=+  parent=
#     Line 26: gene  8162-10479  strand=+  parent=
#
#   ID: gene-bet — appears 3 times
#     Line 32: gene  7925-8036  strand=+  parent=
#     Line 33: gene  8162-8257  strand=+  parent=
#     Line 34: gene  8541-10479  strand=+  parent=
#
#   ID: cds-CAA11584.1 — appears 2 times
#     Line 39: CDS  8164-8257  strand=+  parent=rna-bet
#     Line 40: CDS  8541-9610  strand=+  parent=rna-bet
#
# ================================================================================
# FILE: ../viral_data_all/ncbi_dataset/data_subset/GCA_003108845.1/genomic.gff
# ================================================================================
#
# Features with DUPLICATE IDs (multi-part/discontinuous locations):
#
#   ID: gene-tat — appears 2 times
#     Line 17: gene  5889-6103  strand=+  parent=
#     Line 18: gene  8417-8507  strand=+  parent=
#
#   ID: cds-CAB98190.1 — appears 2 times
#     Line 23: CDS  5889-6103  strand=+  parent=rna-tat
#     Line 24: CDS  8417-8507  strand=+  parent=rna-tat
#
#   ID: gene-rev — appears 2 times
#     Line 26: gene  6018-6103  strand=+  parent=
#     Line 27: gene  8417-8691  strand=+  parent=
#
#   ID: cds-CAB98191.1 — appears 2 times
#     Line 33: CDS  6028-6103  strand=+  parent=rna-rev
#     Line 34: CDS  8417-8691  strand=+  parent=rna-rev
#
# ================================================================================
# FILE: ../viral_data_all/ncbi_dataset/data_subset/GCA_003108945.1/genomic.gff
# ================================================================================
#
# Features with DUPLICATE IDs (multi-part/discontinuous locations):
#
#   ID: cds-CAC38430.2 — appears 2 times
#     Line 10: CDS  844-2151  strand=+  parent=gene-gag-pol
#     Line 11: CDS  2151-5180  strand=+  parent=gene-gag-pol
#
#   ID: gene-tat — appears 2 times
#     Line 18: gene  5917-6107  strand=+  parent=
#     Line 19: gene  8495-8576  strand=+  parent=
#
#   ID: cds-CAC38433.1 — appears 2 times
#     Line 24: CDS  5917-6107  strand=+  parent=rna-tat
#     Line 25: CDS  8495-8576  strand=+  parent=rna-tat
#
#   ID: gene-rev — appears 2 times
#     Line 27: gene  6035-6107  strand=+  parent=
#     Line 28: gene  8495-8733  strand=+  parent=
#
#   ID: cds-CAC38434.1 — appears 2 times
#     Line 34: CDS  6035-6107  strand=+  parent=rna-rev
#     Line 35: CDS  8495-8733  strand=+  parent=rna-rev
#
# ================================================================================
# FILE: ../viral_data_all/ncbi_dataset/data_subset/GCF_002709885.1/genomic.gff
# ================================================================================
#
# Features with DUPLICATE IDs (multi-part/discontinuous locations):
#
#   ID: gene-KNT57_gp001 — appears 2 times
#     Line 563: gene  1-53  strand=-  parent=
#     Line 564: gene  193573-193624  strand=-  parent=
#
#   ID: cds-YP_010278168.1 — appears 2 times
#     Line 565: CDS  193625-193677  strand=-  parent=gene-KNT57_gp001
#     Line 566: CDS  193573-193624  strand=-  parent=gene-KNT57_gp001

# %%
## combining checkpoint .csv files and creating final parsed .csv

all_matches = []
search_terms = ["slip"] # don't want 'ribosome_binding_site'
checkpoint_dir = "../gff_results/gff_checkpoints"
os.makedirs(checkpoint_dir, exist_ok=True)
checkpoint_interval = 10000
checkpoint_count = 0

# --- Merge all checkpoints into one DataFrame ---
checkpoint_files = sorted(
    [f for f in os.listdir(checkpoint_dir) if f.startswith("checkpoint_") and f.endswith(".csv")]
)
print(f"\nMerging {len(checkpoint_files)} checkpoint files...")
df_all = pd.concat([pd.read_csv(f"{checkpoint_dir}/{f}") for f in checkpoint_files], ignore_index=True)
df_all = df_all.drop_duplicates(subset=["record_id", "type", "start", "end", "strand"])
print(f"Found {len(df_all)} unique features matching {search_terms} across {len(gff_files)} files and {len(checkpoint_files)} checkpoint files.")
## CHECK # OF CHECKPOINT FILES ####################
display(df_all.drop(columns=['qualifiers']).head(20))

df_all.to_csv("../tables/gff_parsed.csv")
print("Saved combined df to gff_parsed.csv")
# Out:
# Merging 23 checkpoint files...
# Found 251146 unique features matching ['slip'] across 211307 files and 23 checkpoint files.
#      record_id type  start  end  strand search_term  \
# 0   MG982796.1  CDS     25  594       1        slip
# 1   MG982796.1  CDS    596  724       1        slip
# 2   MT090511.1  CDS      1  570       1        slip
# 3   MT090511.1  CDS    572  760       1        slip
# 4   MK624178.1  CDS     13  582       1        slip
# 5   MK624178.1  CDS    584  772       1        slip
# 6   MN638426.1  CDS     13  582       1        slip
# 7   MN638426.1  CDS    584  772       1        slip
# 8   MW334173.1  CDS     25  594       1        slip
# 9   MW334173.1  CDS    596  784       1        slip
# 10  MN569508.1  CDS     11  580       1        slip
# 11  MN569508.1  CDS    582  770       1        slip
# 12  CY209079.1  CDS     13  582       1        slip
# 13  CY209079.1  CDS    584  772       1        slip
# 14  KT888815.1  CDS      1  570       1        slip
# 15  KT888815.1  CDS    572  760       1        slip
# 16  OQ368232.1  CDS      1  570       1        slip
# 17  OQ368232.1  CDS    572  700       1        slip
# 18  PQ833916.1  CDS      1  570       1        slip
# 19  PQ833916.1  CDS    572  760       1        slip
#
#                                           source_file
# 0   ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 1   ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 2   ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 3   ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 4   ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 5   ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 6   ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 7   ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 8   ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 9   ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 10  ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 11  ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 12  ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 13  ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 14  ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 15  ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 16  ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 17  ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 18  ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 19  ../viral_data_all/ncbi_dataset/data_subset/GCA...
# Saved combined df to gff_parsed.csv

# %% [markdown]
# # CHECKING

# %%
df = pd.read_csv("../tables/gff_parsed.csv")

# %%
df[df['search_term'] == 'slip']
# Out:
#         Unnamed: 0   record_id type  start   end  strand  \
# 0                0  MG982796.1  CDS     24   594       1
# 1                1  MG982796.1  CDS    595   724       1
# 2                4  MT090511.1  CDS      0   570       1
# 3                5  MT090511.1  CDS    571   760       1
# 4                8  MK624178.1  CDS     12   582       1
# ...            ...         ...  ...    ...   ...     ...
# 310449      561748  PQ011362.1  CDS    571   760       1
# 310450      872201  AJ302647.1  CDS    843  2151       1
# 310451      872202  AJ302647.1  CDS   2150  5180       1
# 310452      872203  AJ302646.1  CDS    843  2151       1
# 310453      872204  AJ302646.1  CDS   2150  5180       1
#
#                                                qualifiers search_term  \
# 0       {'ID': ['cds-AVT55874.1'], 'Parent': ['gene-PA...        slip
# 1       {'ID': ['cds-AVT55874.1'], 'Parent': ['gene-PA...        slip
# 2       {'ID': ['cds-QIC52522.1'], 'Parent': ['gene-PA...        slip
# 3       {'ID': ['cds-QIC52522.1'], 'Parent': ['gene-PA...        slip
# 4       {'ID': ['cds-QBL91539.1'], 'Parent': ['gene-PA...        slip
# ...                                                   ...         ...
# 310449  {'ID': ['cds-XCO67773.1'], 'Parent': ['gene-PA...        slip
# 310450  {'ID': ['cds-CAC38421.2'], 'Parent': ['gene-ga...        slip
# 310451  {'ID': ['cds-CAC38421.2'], 'Parent': ['gene-ga...        slip
# 310452  {'ID': ['cds-CAC38430.2'], 'Parent': ['gene-ga...        slip
# 310453  {'ID': ['cds-CAC38430.2'], 'Parent': ['gene-ga...        slip
#
#                                               source_file
# 0       ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 1       ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 2       ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 3       ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 4       ../viral_data_all/ncbi_dataset/data_subset/GCA...
# ...                                                   ...
# 310449  ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 310450  ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 310451  ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 310452  ../viral_data_all/ncbi_dataset/data_subset/GCA...
# 310453  ../viral_data_all/ncbi_dataset/data_subset/GCA...
#
# [251146 rows x 9 columns]
